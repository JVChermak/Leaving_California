# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from datetime import datetime
import numpy as np

# %%
# Read data
df_census = pd.read_csv('Resources/Census.csv')
df_census
# Out:
#      Year                 State  Home Value <$50k (%)  \
# 0    2010               Alabama                   9.1
# 1    2010                Alaska                   2.0
# 2    2010               Arizona                   4.0
# 3    2010              Arkansas                  12.0
# 4    2010            California                   1.5
# ..    ...                   ...                   ...
# 463  2018               Florida                   2.6
# 464  2018         Massachusetts                   1.0
# 465  2018  District of Columbia                   0.8
# 466  2018                  Utah                   1.9
# 467  2018              New York                   2.2
#
#      Home Value $50k-$99,999k (%)  Home Value $100k-$149,999k (%)  \
# 0                            23.6                            20.3
# 1                             2.9                             9.6
# 2                            13.4                            20.5
# 3                            27.0                            23.9
# 4                             3.4                             6.0
# ..                            ...                             ...
# 463                           6.4                             NaN
# 464                           0.8                             NaN
# 465                           0.6                             NaN
# 466                           1.2                             NaN
# 467                           8.0                             NaN
#
#      Home Value $150k-$199,999k (%)  Home Value $200k-$299,999k (%)  \
# 0                              17.8                            16.8
# 1                              15.6                            35.2
# 2                              19.5                            21.4
# 3                              16.2                            12.2
# 4                               8.6                            17.4
# ..                              ...                             ...
# 463                             NaN                             NaN
# 464                             NaN                             NaN
# 465                             NaN                             NaN
# 466                             NaN                             NaN
# 467                             NaN                             NaN
#
#      Home Value $100k-$299,999 (%)  Home Value $300k-$499,999k (%)  \
# 0                              NaN                             8.7
# 1                              NaN                            26.5
# 2                              NaN                            14.4
# 3                              NaN                             6.4
# 4                              NaN                            29.1
# ..                             ...                             ...
# 463                           55.1                            24.6
# 464                           26.7                            36.2
# 465                            8.9                            27.1
# 466                           44.5                            37.5
# 467                           34.6                            23.8
#
#      Home Value $500k+ (%)  ...  Income $10k-$24,999 (%)  \
# 0                      3.7  ...                     10.4
# 1                      8.1  ...                      4.0
# 2                      6.8  ...                      8.8
# 3                      2.1  ...                     10.9
# 4                     34.0  ...                      5.9
# ..                     ...  ...                      ...
# 463                    NaN  ...                      7.3
# 464                    NaN  ...                      3.1
# 465                    NaN  ...                      2.8
# 466                    NaN  ...                      3.7
# 467                    NaN  ...                      4.2
#
#      Income $25k-$34,999 (%)  Income $35k-$49,999 (%)  \
# 0                        8.7                     15.5
# 1                        5.1                      8.4
# 2                        8.2                     14.1
# 3                       10.6                     16.8
# 4                        5.2                     10.0
# ..                       ...                      ...
# 463                      6.4                     11.2
# 464                      3.1                      5.5
# 465                      1.9                      2.9
# 466                      4.3                      8.1
# 467                      3.9                      6.8
#
#      Income $50k-$74,999 (%)  Income $75k-$99,999 (%)  \
# 0                       21.7                     15.6
# 1                       17.8                     17.0
# 2                       22.6                     16.2
# 3                       22.8                     15.1
# 4                       17.7                     15.9
# ..                       ...                      ...
# 463                     18.5                     15.6
# 464                     13.0                     13.0
# 465                      9.0                     10.2
# 466                     19.1                     18.3
# 467                     14.3                     14.2
#
#      Income $100k-$149,999 (%)  Income $150k+ (%)  Median Income ($)(1000X)  \
# 0                         15.6                8.7                    61.964
# 1                         27.3               19.1                    94.747
# 2                         17.2               10.2                    66.539
# 3                         14.1                7.1                    59.393
# 4                         22.1               21.2                    88.444
# ..                         ...                ...                       ...
# 463                       19.8               18.4                    80.372
# 464                       23.6               37.3                   121.565
# 465                       20.3               50.6                   151.147
# 466                       26.2               19.3                    93.060
# 467                       23.3               31.6                   108.546
#
#      Median Housing Cost (monthly) ($)  Median Real Estate Taxes ($)
# 0                                 1130                         568.0
# 1                                 1772                        3177.0
# 2                                 1442                        1489.0
# 3                                  987                         703.0
# 4                                 2242                        3284.0
# ..                                 ...                           ...
# 463                               1471                        2151.0
# 464                               2207                        4801.0
# 465                               2506                        3691.0
# 466                               1531                        1788.0
# 467                               2098                        5837.0
#
# [468 rows x 30 columns]

# %%
# Filter data to just get information about California
ca_housing_df = df_census[df_census['State'] == 'California']
ca_housing_df
# Out:
#      Year       State  Home Value <$50k (%)  Home Value $50k-$99,999k (%)  \
# 4    2010  California                   1.5                           3.4
# 56   2011  California                   1.6                           3.8
# 108  2012  California                   1.7                           4.1
# 160  2013  California                   2.8                           3.2
# 212  2014  California                   2.7                           2.1
# 264  2015  California                   1.1                           1.7
# 316  2016  California                   1.1                           1.4
# 368  2017  California                   1.0                           1.1
# 425  2018  California                   1.0                           1.0
#
#      Home Value $100k-$149,999k (%)  Home Value $150k-$199,999k (%)  \
# 4                               6.0                             8.6
# 56                              7.0                             9.0
# 108                             7.2                             9.3
# 160                             5.7                             8.0
# 212                             4.1                             6.2
# 264                             NaN                             NaN
# 316                             NaN                             NaN
# 368                             NaN                             NaN
# 425                             NaN                             NaN
#
#      Home Value $200k-$299,999k (%)  Home Value $100k-$299,999 (%)  \
# 4                              17.4                            NaN
# 56                             17.9                            NaN
# 108                            18.0                            NaN
# 160                            16.3                            NaN
# 212                            14.7                            NaN
# 264                             NaN                           22.2
# 316                             NaN                           19.4
# 368                             NaN                           16.6
# 425                             NaN                           14.1
#
#      Home Value $300k-$499,999k (%)  Home Value $500k+ (%)  ...  \
# 4                              29.1                   34.0  ...
# 56                             28.5                   32.2  ...
# 108                            28.5                   31.3  ...
# 160                            29.2                   34.9  ...
# 212                            30.0                   40.2  ...
# 264                            30.5                    NaN  ...
# 316                            29.4                    NaN  ...
# 368                            28.5                    NaN  ...
# 425                            27.1                    NaN  ...
#
#      Income $10k-$24,999 (%)  Income $25k-$34,999 (%)  \
# 4                        5.9                      5.2
# 56                       6.0                      5.3
# 108                      5.7                      5.2
# 160                      5.6                      5.0
# 212                      5.4                      5.0
# 264                      5.1                      4.6
# 316                      4.7                      4.2
# 368                      4.5                      3.9
# 425                      4.1                      3.7
#
#      Income $35k-$49,999 (%)  Income $50k-$74,999 (%)  \
# 4                       10.0                     17.7
# 56                       9.8                     17.3
# 108                      9.6                     17.1
# 160                      9.1                     16.8
# 212                      8.5                     16.0
# 264                      8.2                     15.4
# 316                      7.8                     14.8
# 368                      7.2                     13.8
# 425                      6.6                     13.3
#
#      Income $75k-$99,999 (%)  Income $100k-$149,999 (%)  Income $150k+ (%)  \
# 4                       15.9                       22.1               21.2
# 56                      15.3                       21.6               22.3
# 108                     15.2                       21.8               23.2
# 160                     14.8                       21.7               25.0
# 212                     14.8                       21.8               26.4
# 264                     14.5                       22.2               28.0
# 316                     14.1                       21.8               30.6
# 368                     13.6                       22.6               32.5
# 425                     13.2                       22.1               34.9
#
#      Median Income ($)(1000X)  Median Housing Cost (monthly) ($)  \
# 4                      88.444                               2242
# 56                     89.279                               2182
# 108                    91.024                               2119
# 160                    93.538                               2059
# 212                    96.305                               2068
# 264                   100.223                               2123
# 316                   103.266                               2188
# 368                   108.609                               2269
# 425                   113.027                               2345
#
#      Median Real Estate Taxes ($)
# 4                          3284.0
# 56                         3291.0
# 108                        3336.0
# 160                        3412.0
# 212                        3548.0
# 264                           NaN
# 316                           NaN
# 368                        4174.0
# 425                        4479.0
#
# [9 rows x 30 columns]

# %%
# Visually inspect relationship between Median Housing Cost and Year
x = ca_housing_df['Year']
y = ca_housing_df['Median Housing Cost (monthly) ($)']
plt.scatter(x, y)
plt.xlabel('Years')
plt.ylabel('Median Monthly Housing Cost (USD)')
plt.title('California Monthly Median Housing Costs')
plt.show()

# %%
# Set independent variable
X = ca_housing_df.Year.values.reshape(-1,1)
X
# Out:
# array([[2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018]])

# %%
# Set dependent variable
y1 = ca_housing_df['Median Housing Cost (monthly) ($)']

# %%
# Create model and fit
model = LinearRegression()
model.fit(X,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict using the model
y_pred = model.predict(X)

# Visualize the regression line
plt.scatter(X,y1)
plt.plot(X, y_pred, color='red')
plt.xlabel('Years')
plt.ylabel('Median Monthly Housing Cost (USD)')
plt.title('California Median Monthly Housing Costs')
plt.show()
plt.savefig('img/median_housing1.png')

# %%
# Find the equation for the regression line
print(model.coef_)
print(model.intercept_)
# Out:
# [14.58333333]
# -27193.61111111112

# %%
# Predict the cost of housing in 2030
m = model.coef_
b = model.intercept_
m*2030 - b
# Out:
# array([56797.77777778])

# %%
# Predict the cost of housing in 2030
m1 = model.coef_
b1 = model.intercept_
print(f'The predicted monthly cost of housing in 2030 is ${m1*2030 - b1} based on 2010-2018 census data.')
# Out:
# The predicted monthly cost of housing in 2030 is $[56797.77777778].

# %%
# Try a linear regression with only 2013 to 2018 data
recent_ca_housing_df = ca_housing_df[ca_housing_df['Year'] >= 2013]
recent_ca_housing_df
# Out:
#      Year       State  Home Value <$50k (%)  Home Value $50k-$99,999k (%)  \
# 160  2013  California                   2.8                           3.2
# 212  2014  California                   2.7                           2.1
# 264  2015  California                   1.1                           1.7
# 316  2016  California                   1.1                           1.4
# 368  2017  California                   1.0                           1.1
# 425  2018  California                   1.0                           1.0
#
#      Home Value $100k-$149,999k (%)  Home Value $150k-$199,999k (%)  \
# 160                             5.7                             8.0
# 212                             4.1                             6.2
# 264                             NaN                             NaN
# 316                             NaN                             NaN
# 368                             NaN                             NaN
# 425                             NaN                             NaN
#
#      Home Value $200k-$299,999k (%)  Home Value $100k-$299,999 (%)  \
# 160                            16.3                            NaN
# 212                            14.7                            NaN
# 264                             NaN                           22.2
# 316                             NaN                           19.4
# 368                             NaN                           16.6
# 425                             NaN                           14.1
#
#      Home Value $300k-$499,999k (%)  Home Value $500k+ (%)  ...  \
# 160                            29.2                   34.9  ...
# 212                            30.0                   40.2  ...
# 264                            30.5                    NaN  ...
# 316                            29.4                    NaN  ...
# 368                            28.5                    NaN  ...
# 425                            27.1                    NaN  ...
#
#      Income $10k-$24,999 (%)  Income $25k-$34,999 (%)  \
# 160                      5.6                      5.0
# 212                      5.4                      5.0
# 264                      5.1                      4.6
# 316                      4.7                      4.2
# 368                      4.5                      3.9
# 425                      4.1                      3.7
#
#      Income $35k-$49,999 (%)  Income $50k-$74,999 (%)  \
# 160                      9.1                     16.8
# 212                      8.5                     16.0
# 264                      8.2                     15.4
# 316                      7.8                     14.8
# 368                      7.2                     13.8
# 425                      6.6                     13.3
#
#      Income $75k-$99,999 (%)  Income $100k-$149,999 (%)  Income $150k+ (%)  \
# 160                     14.8                       21.7               25.0
# 212                     14.8                       21.8               26.4
# 264                     14.5                       22.2               28.0
# 316                     14.1                       21.8               30.6
# 368                     13.6                       22.6               32.5
# 425                     13.2                       22.1               34.9
#
#      Median Income ($)(1000X)  Median Housing Cost (monthly) ($)  \
# 160                    93.538                               2059
# 212                    96.305                               2068
# 264                   100.223                               2123
# 316                   103.266                               2188
# 368                   108.609                               2269
# 425                   113.027                               2345
#
#      Median Real Estate Taxes ($)
# 160                        3412.0
# 212                        3548.0
# 264                           NaN
# 316                           NaN
# 368                        4174.0
# 425                        4479.0
#
# [6 rows x 30 columns]

# %%
# Set independent variable
X2 = recent_ca_housing_df['Year'].values.reshape(-1,1)

# Set dependent variable
y2 = recent_ca_housing_df['Median Housing Cost (monthly) ($)']

# Create model and fit
model = LinearRegression()
model.fit(X2,y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict with model
y_pred2 = model.predict(X2)

# Visualize the regression line
plt.scatter(X2,y2)
plt.plot(X2, y_pred2, color='red')
plt.xlabel('Years')
plt.ylabel('Median Monthly Housing Cost (USD)')
plt.title('California Median Monthly Housing Cost (USD)')
plt.show()
plt.savefig('img/median_housing2.png')

# %%
# Find the equation for the regression line
print(model.coef_)
print(model.intercept_)
# Out:
# [59.94285714]
# -118639.49523809525

# %%
# Predict Median Housing Cost in 2030
m2 = model.coef_
b2 = model.intercept_
print(f'The predicted monthly cost of housing in 2030 is ${m2*2030 - b2} based on 2013-2018 census data.')
# Out:
# The predicted monthly cost of housing in 2030 is $[240323.4952381].

# %% [markdown]
# ## Create Linear Regression with Zillow data

# %%
# Create Zillow CA DataFrame
zillow_ca_df = pd.read_csv('Resources/zillow_data.csv')
zillow_ca_df
# Out:
#    RegionID  RegionName  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# 0         9  California         1  161327.0  161154.0  161021.0  160947.0
#
#     1996-08   1996-09   1996-10  ...  2019-04  2019-05  2019-06  2019-07  \
# 0  160952.0  161001.0  161175.0  ...   553549   554281   555050   556081
#
#    2019-08  2019-09  2019-10  2019-11  2019-12  2020-01
# 0   557569   559533   561558   563566   566414   569687
#
# [1 rows x 289 columns]

# %%
# Remove RegionID and SizeRank columns
zillow_ca_df.drop(columns=['RegionID', 'SizeRank'], inplace=True)
zillow_ca_df
# Out:
#    RegionName   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0  California  161327.0  161154.0  161021.0  160947.0  160952.0  161001.0
#
#     1996-10   1996-11   1996-12  ...  2019-04  2019-05  2019-06  2019-07  \
# 0  161175.0  161376.0  161653.0  ...   553549   554281   555050   556081
#
#    2019-08  2019-09  2019-10  2019-11  2019-12  2020-01
# 0   557569   559533   561558   563566   566414   569687
#
# [1 rows x 287 columns]

# %%
# Convert to tall DataFrame
zillow_ca_df = pd.melt(zillow_ca_df, id_vars=['RegionName'], var_name='Time', value_name='Typical_Home_Value')
zillow_ca_df.head(10)
# Out:
#    RegionName     Time  Typical_Home_Value
# 0  California  1996-04            161327.0
# 1  California  1996-05            161154.0
# 2  California  1996-06            161021.0
# 3  California  1996-07            160947.0
# 4  California  1996-08            160952.0
# 5  California  1996-09            161001.0
# 6  California  1996-10            161175.0
# 7  California  1996-11            161376.0
# 8  California  1996-12            161653.0
# 9  California  1997-01            161695.0

# %%
zillow_ca_df.dtypes
# Out:
# RegionName             object
# Time                   object
# Typical_Home_Value    float64
# dtype: object

# %%
# Convert Time to datetime
zillow_ca_df['Time'] = pd.to_datetime(zillow_ca_df['Time'], format='%Y-%m')
zillow_ca_df
# Out:
#      RegionName       Time  Typical_Home_Value
# 0    California 1996-04-01            161327.0
# 1    California 1996-05-01            161154.0
# 2    California 1996-06-01            161021.0
# 3    California 1996-07-01            160947.0
# 4    California 1996-08-01            160952.0
# ..          ...        ...                 ...
# 281  California 2019-09-01            559533.0
# 282  California 2019-10-01            561558.0
# 283  California 2019-11-01            563566.0
# 284  California 2019-12-01            566414.0
# 285  California 2020-01-01            569687.0
#
# [286 rows x 3 columns]

# %%
# Visually inspect Zillow data
plt.plot_date(zillow_ca_df.Time, zillow_ca_df.Typical_Home_Value)
plt.xlabel('Time')
plt.ylabel('Typical Home Value in USD')
plt.title('California Typical Home Value from Zillow')
plt.show
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# The 2008 recession is visible in terms of home value, but home values have continued on the rise since 2012. Check linear regression to see if this was a "course correction".

# %%
# Create Months column that represents the number of months since 1994-04
zillow_ca_df['Months'] = zillow_ca_df.index
zillow_ca_df
# Out:
#      RegionName       Time  Typical_Home_Value  Months
# 0    California 1996-04-01            161327.0       0
# 1    California 1996-05-01            161154.0       1
# 2    California 1996-06-01            161021.0       2
# 3    California 1996-07-01            160947.0       3
# 4    California 1996-08-01            160952.0       4
# ..          ...        ...                 ...     ...
# 281  California 2019-09-01            559533.0     281
# 282  California 2019-10-01            561558.0     282
# 283  California 2019-11-01            563566.0     283
# 284  California 2019-12-01            566414.0     284
# 285  California 2020-01-01            569687.0     285
#
# [286 rows x 4 columns]

# %%
zillow_ca_df.dtypes
# Out:
# RegionName                    object
# Time                  datetime64[ns]
# Typical_Home_Value           float64
# Months                         int64
# dtype: object

# %%
# Set independent variable
X3 = zillow_ca_df['Months'].values.reshape(-1,1)

# Set dependent variable
y3 = zillow_ca_df['Typical_Home_Value']

# Create model and fit
z_model = LinearRegression()
z_model.fit(X3,y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict with Zillow model
y_predz = z_model.predict(X3)

# Visualize the regression line
plt.scatter(X3,y3)
plt.plot(X3, y_predz, color='red')
plt.xlabel('Time')
plt.ylabel('Typical Home Value in USD')
plt.title('California Typical Home Value from Zillow')
plt.show()
plt.savefig('img/median_home_value1.png')

# %%
# Find the equation for the regression line
print(z_model.coef_)
print(z_model.intercept_)
# Out:
# [1191.63336997]
# 195615.22380058962

# %%
# Predict home value in 2030 by adding 120 months to 2020-01
m3 = z_model.coef_
b3 = z_model.intercept_
x = 285 + 120
print(f'The predicted typical home value in 2030 is ${m3 * x + b3} based on April 1996 to January 2020 Zillow data.')
# Out:
# The predicted typical home value in 2030 is $[678226.73863749] based on Zillow data.

# %%
# Check Census Median Home Value data
X4 = ca_housing_df['Year'].values.reshape(-1,1)
y4 = ca_housing_df['Median Home Value ($)(1000X)']

# Create model and fit
model = LinearRegression()
model.fit(X4,y4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict with model
y_pred4 = model.predict(X4)

# Visualize the regression line
plt.scatter(X4,y4)
plt.plot(X4, y_pred4, color='red')
plt.xlabel('Years')
plt.ylabel('Median Home Value (USD)')
plt.title('California Median Home Value from Census')
plt.show()
plt.savefig('img/median_home_value2.png')

# %%
# Find the equation for the regression line
print(model.coef_)
print(model.intercept_)
# Out:
# [26.57666667]
# -53085.57333333334

# %%
# Predict Median Home Value in 2030
m4 = model.coef_
b4 = model.intercept_
print(f'The predicted median home value in 2030 is {(m4*2030 + b4) * 1000} based on 2010-2018 census data.')
# Out:
# The predicted median home value in 2030 is [865060.] according to census.gov data.
