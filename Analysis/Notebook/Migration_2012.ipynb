# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2012.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States1                310,212,755  +/- 25,814
# 1                 Alabama                  4,764,428   +/- 3,589
# 2                  Alaska                    721,186   +/- 1,290
# 3                 Arizona                  6,468,907   +/- 3,874
# 4                Arkansas                  2,912,680   +/- 2,753
#
#   Same residence 1 year ago        MOE.1  \
# 0               263,612,596  +/- 229,733
# 1                 4,054,260   +/- 21,464
# 2                   592,551    +/- 8,741
# 3                 5,242,674   +/- 32,185
# 4                 2,453,347   +/- 16,841
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 37,696,597  +/- 211,307
# 1                                    590,326   +/- 19,701
# 2                                     90,613    +/- 7,239
# 3                                    953,789   +/- 28,803
# 4                                    373,046   +/- 14,543
#
#   Different state of residence 1 year ago       MOE.3  Alabama  ... Wyoming  \
# 0                               7,070,345  +/- 58,599  109,210  ...  32,228
# 1                                 104,600   +/- 8,482      NaN  ...      88
# 2                                  33,415   +/- 4,385    1,097  ...     136
# 3                                 232,457  +/- 14,183    1,331  ...   2,786
# 4                                  76,948   +/- 7,223      374  ...   1,498
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 5,150  1,833,217  +/- 32,633      74,500  +/- 8,156           15,876
# 1    +/- 107     15,242   +/- 2,994         619    +/- 551                0
# 2    +/- 217      4,607   +/- 1,235          25     +/- 43              272
# 3  +/- 1,401     39,987   +/- 4,295       1,791  +/- 1,662              447
# 4  +/- 2,098      9,339   +/- 1,679           0    +/- 184                4
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 3,083       1,742,841  +/- 31,206
# 1    +/- 184          14,623   +/- 2,857
# 2    +/- 312           4,310   +/- 1,199
# 3    +/- 401          37,749   +/- 4,037
# 4      +/- 7           9,335   +/- 1,680
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 0 null values
# Column MOE.56 has 0 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States1  310,212,755  263,612,596  37,696,597       7,070,345
# 1         Alabama    4,764,428    4,054,260     590,326         104,600
# 2          Alaska      721,186      592,551      90,613          33,415
# 3         Arizona    6,468,907    5,242,674     953,789         232,457
# 4        Arkansas    2,912,680    2,453,347     373,046          76,948
#
#    Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  109,210  84,068  206,842   64,967    566,986  ...   163,843  402,187
# 1      NaN   1,004      962      660      3,077  ...    10,539    7,468
# 2    1,097     NaN    1,520      196      3,494  ...       451    1,488
# 3    1,331   3,717      NaN    1,214     44,889  ...     5,075   14,788
# 4      374     855    1,677      NaN      3,525  ...     4,195   11,767
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  82,165  20,056  238,540    180,462        47,425    97,724  32,228
# 1     579       0    3,170      1,034           128       760      88
# 2     330      79    1,265      3,725             0       206     136
# 3   5,916     207    2,763     13,247           765     3,765   2,786
# 4     269       0    1,159        251            84       695   1,498
#
#        Total
# 0  1,833,217
# 1     15,242
# 2      4,607
# 3     39,987
# 4      9,339
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2012)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2012         United States1  310,212,755  263,612,596  37,696,597
# 1   2012                Alabama    4,764,428    4,054,260     590,326
# 2   2012                 Alaska      721,186      592,551      90,613
# 3   2012                Arizona    6,468,907    5,242,674     953,789
# 4   2012               Arkansas    2,912,680    2,453,347     373,046
# 5   2012             California   37,572,738   31,777,868   5,046,618
# 6   2012               Colorado    5,123,944    4,131,357     751,921
# 7   2012            Connecticut    3,555,319    3,114,940     334,918
# 8   2012               Delaware      906,576      782,216      86,003
# 9   2012  District of Columbia       624,847      500,267      61,992
# 10  2012                Florida   19,114,620   16,032,617   2,380,288
# 11  2012                Georgia    9,796,547    8,231,384   1,236,302
# 12  2012                 Hawaii    1,374,852    1,164,145     134,827
# 13  2012                  Idaho    1,573,036    1,296,975     210,151
# 14  2012               Illinois   12,725,119   11,009,321   1,441,191
# 15  2012                Indiana    6,457,067    5,493,090     805,228
# 16  2012                   Iowa    3,035,469    2,585,979     362,938
# 17  2012                 Kansas    2,848,708    2,361,899     381,695
# 18  2012               Kentucky    4,328,626    3,676,472     521,511
# 19  2012              Louisiana    4,545,914    3,912,023     528,406
# 20  2012                  Maine    1,315,586    1,132,344     151,438
# 21  2012               Maryland    5,816,472    5,068,457     549,973
# 22  2012          Massachusetts    6,580,641    5,752,166     626,380
# 23  2012               Michigan    9,778,980    8,330,990   1,268,105
# 24  2012              Minnesota    5,315,228    4,536,303     653,012
# 25  2012            Mississippi    2,947,696    2,529,377     339,807
# 26  2012               Missouri    5,951,913    4,965,459     801,093
# 27  2012                Montana      995,544      829,489     126,463
# 28  2012               Nebraska    1,829,420    1,540,361     237,937
# 29  2012                 Nevada    2,725,280    2,105,070     481,496
# 30  2012          New Hampshire    1,309,203    1,127,376     125,118
# 31  2012             New Jersey    8,772,744    7,929,570     655,465
# 32  2012             New Mexico    2,060,595    1,769,341     226,243
# 33  2012               New York   19,352,153   17,202,134   1,723,117
# 34  2012         North Carolina    9,640,490    8,167,830   1,149,080
# 35  2012           North Dakota      689,838      563,978      84,294
# 36  2012                   Ohio   11,414,635    9,735,390   1,440,815
# 37  2012               Oklahoma    3,762,311    3,107,367     531,347
# 38  2012                 Oregon    3,857,465    3,158,450     560,673
# 39  2012           Pennsylvania   12,630,082   11,107,110   1,252,378
# 40  2012           Rhode Island    1,040,527      899,551     101,165
# 41  2012         South Carolina    4,668,886    3,929,626     564,350
# 42  2012           South Dakota      821,669      676,014     115,606
# 43  2012              Tennessee    6,378,278    5,396,833     783,077
# 44  2012                  Texas   25,711,791   21,354,247   3,656,070
# 45  2012                   Utah    2,805,440    2,324,019     373,980
# 46  2012                Vermont      620,224      532,237      61,242
# 47  2012               Virginia    8,085,389    6,857,430     915,242
# 48  2012             Washington    6,815,763    5,648,199     904,695
# 49  2012          West Virginia    1,837,518    1,613,322     174,112
#
#    Different state  Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        7,070,345  109,210  84,068  206,842   64,967  ...   163,843  402,187
# 1          104,600      NaN   1,004      962      660  ...    10,539    7,468
# 2           33,415    1,097     NaN    1,520      196  ...       451    1,488
# 3          232,457    1,331   3,717      NaN    1,214  ...     5,075   14,788
# 4           76,948      374     855    1,677      NaN  ...     4,195   11,767
# 5          493,641    2,509   6,995   38,916    3,472  ...     5,802   43,005
# 6          205,060    3,108   3,457   10,589    1,043  ...     2,535   17,355
# 7           80,311       46     439    3,167      200  ...       260    3,279
# 8           34,757      119     692      188        0  ...       344      133
# 9           53,830       79   1,247      902       35  ...       577    1,473
# 10         537,148   18,599  10,704    6,473    3,321  ...    16,275   28,564
# 11         277,466   13,864   2,654    6,657    1,041  ...    17,606   16,198
# 12          55,145      608   1,417    1,865       24  ...     1,314    3,300
# 13          59,283      575   1,198    2,424      291  ...     1,957    1,352
# 14         208,755      883   2,250    7,139    1,587  ...     4,648   16,780
# 15         134,137    1,625     479    2,763      564  ...     3,547    4,490
# 16          75,760      503     951    1,590      451  ...     1,148    3,553
# 17          88,284      853     333    3,094    2,158  ...     1,542    8,468
# 18         112,787    4,137     304    1,103      518  ...    10,064    3,345
# 19          91,215    2,329     403    2,021    3,645  ...     2,348   24,488
# 20          27,523      129      38      230        0  ...       985      496
# 21         154,983    1,261   1,947      760      136  ...     1,800    5,612
# 22         142,577      636     890    1,972      394  ...       823    3,694
# 23         133,981    2,341   1,152    7,168      906  ...     3,259    8,638
# 24         101,042    1,299     523    3,065      375  ...     1,738    4,001
# 25          73,500    5,141       0      710    2,680  ...    11,643    7,230
# 26         162,930    1,333   2,186    2,297    9,434  ...     3,122    9,278
# 27          37,690       31     726    1,548       63  ...        45    1,393
# 28          43,266      245     626    2,406      363  ...       232    3,130
# 29         124,285      761   2,161    8,748      353  ...     1,699    5,484
# 30          50,484        0     437      440        0  ...        77    2,150
# 31         130,223      779     359    1,328       57  ...     1,400    2,509
# 32          54,693      787     320    6,391      410  ...       338   11,955
# 33         270,053    1,364   4,002    4,146      247  ...     1,279   11,231
# 34         273,149    4,329   1,458    3,493      861  ...     9,230   12,638
# 35          38,213       83      70    1,571        0  ...       746    1,414
# 36         196,391    3,705   2,207    4,929      884  ...     3,542   11,760
# 37         108,972    1,030   1,279    2,974    5,777  ...     2,471   25,508
# 38         118,925      373   2,513    7,954      165  ...       802    3,347
# 39         215,500    1,926   1,658    3,529      573  ...     1,273    6,768
# 40          33,446       20       0       93        0  ...       120      823
# 41         156,705    1,665   1,244    2,222      839  ...     3,550    5,351
# 42          26,051        0     855      435      227  ...       507    1,715
# 43         177,098   12,116   1,281    2,250    3,306  ...       NaN    8,716
# 44         507,752    9,993   6,759   18,908   13,781  ...    10,368      NaN
# 45          87,870      126   2,819    7,966      361  ...       863    3,605
# 46          24,431       16      93      127        0  ...       193      493
# 47         250,653    2,515   1,906    2,420      445  ...     6,189   12,944
# 48         215,494    1,507   4,328    8,362    1,413  ...     3,206   14,196
# 49          47,125      477     306       79        0  ...     1,061      622
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   82,165  20,056  238,540    180,462        47,425    97,724  32,228
# 1      579       0    3,170      1,034           128       760      88
# 2      330      79    1,265      3,725             0       206     136
# 3    5,916     207    2,763     13,247           765     3,765   2,786
# 4      269       0    1,159        251            84       695   1,498
# 5   12,172     544   15,625     34,569         1,413     5,681   1,886
# 6    6,398     503    3,796      4,853           837     3,000   5,602
# 7       45     709    1,729      1,593           174       711     104
# 8      166       0    1,746         29           161         0       0
# 9      116     267    9,537        481           293       721     215
# 10   2,499   2,747   25,697      4,943         3,533     6,216     773
# 11      20      84   10,702      1,965         1,237     3,441     106
# 12   2,183       0    1,393      5,920           197       295      50
# 13   6,617       0      269     10,398             0       225     677
# 14   1,154     156    4,311      2,704         1,221    14,414     302
# 15     105       0    1,932        258           507     1,727   1,681
# 16     886       0      268        919            22     3,607     392
# 17      97      70    1,705      3,265           139       486     278
# 18     464      45    3,319      1,988         3,346     1,395       0
# 19     277      45    1,857      1,581           238       682     146
# 20     200     349      573        118            51         0      59
# 21   1,061     589   20,579      1,431         1,957       460       0
# 22   1,027   2,534    4,098      1,653           385       584     264
# 23     819      60    3,057      2,146           353     4,768   1,277
# 24     429      77    1,037      1,685             0    17,618     213
# 25     454       0    1,929        433             0       611     307
# 26   3,287     318    2,609      2,312           148     2,636     810
# 27     260      87      156      4,783             0       750     934
# 28     229      79    1,076      1,327           111       316     917
# 29   4,605     121    1,135      2,997           100     1,046     766
# 30     557   2,960      660        113            80       239      71
# 31     425      35    5,024      1,847           297       680      23
# 32   1,382      81    1,560      1,251             0       321      95
# 33     622   2,764    7,939      2,614           921       979     396
# 34   1,189     445   26,759      5,915         2,677     2,266     604
# 35      43     758      403      1,604             0       543     365
# 36     197     364    3,193      2,862         7,820       974     202
# 37   2,588     197    1,749      1,574           368     1,061      45
# 38   4,793     367      676     21,224           593       426     765
# 39   1,276   1,012   11,960      1,787         6,762     1,550     434
# 40       0      53    1,008        287             0       135      21
# 41     566     298    9,377      1,629         1,345       832       0
# 42     388       5      340      1,026           131       314     979
# 43     784     133    8,008      1,876         3,248     1,622     358
# 44   4,610     113   17,734     11,630         1,729     4,192   2,472
# 45     NaN      39    1,369      3,529             0     1,445   2,216
# 46      81     NaN      728         98             0       151      96
# 47   2,092     423      NaN      4,160         3,839     1,258     143
# 48   5,298     223    3,839        NaN           215     1,168     394
# 49       0      54    6,317        297           NaN       470     252
#
#         Total
# 0   1,833,217
# 1      15,242
# 2       4,607
# 3      39,987
# 4       9,339
# 5     254,611
# 6      35,606
# 7      25,150
# 8       3,600
# 9       8,758
# 10    164,567
# 11     51,395
# 12     20,735
# 13      6,627
# 14     65,852
# 15     24,612
# 16     10,792
# 17     16,830
# 18     17,856
# 19     14,270
# 20      4,281
# 21     43,059
# 22     59,518
# 23     45,904
# 24     24,871
# 25      5,012
# 26     22,431
# 27      1,902
# 28      7,856
# 29     14,429
# 30      6,225
# 31     57,486
# 32     10,318
# 33    156,849
# 34     50,431
# 35      3,353
# 36     42,039
# 37     14,625
# 38     19,417
# 39     55,094
# 40      6,365
# 41     18,205
# 42      3,998
# 43     21,270
# 44    193,722
# 45     19,571
# 46      2,314
# 47     62,064
# 48     47,375
# 49      2,959
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2012  United States1   310212755   263612596    37696597          7070345
# 1  2012         Alabama     4764428     4054260      590326           104600
# 2  2012          Alaska      721186      592551       90613            33415
# 3  2012         Arizona     6468907     5242674      953789           232457
# 4  2012        Arkansas     2912680     2453347      373046            76948
#
#     Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  109210.0  84068.0  206842.0   64967.0  ...   163843.0  402187.0  82165.0
# 1       NaN   1004.0     962.0     660.0  ...    10539.0    7468.0    579.0
# 2    1097.0      NaN    1520.0     196.0  ...      451.0    1488.0    330.0
# 3    1331.0   3717.0       NaN    1214.0  ...     5075.0   14788.0   5916.0
# 4     374.0    855.0    1677.0       NaN  ...     4195.0   11767.0    269.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  20056.0  238540.0    180462.0        47425.0    97724.0  32228.0  1833217
# 1      0.0    3170.0      1034.0          128.0      760.0     88.0    15242
# 2     79.0    1265.0      3725.0            0.0      206.0    136.0     4607
# 3    207.0    2763.0     13247.0          765.0     3765.0   2786.0    39987
# 4      0.0    1159.0       251.0           84.0      695.0   1498.0     9339
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2012  California    37572738    31777868     5046618           493641
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 5   2509.0  6995.0  38916.0    3472.0  ...     5802.0  43005.0  12172.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5    544.0   15625.0     34569.0         1413.0     5681.0   1886.0  254611
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2012  California    37572738    31777868     5046618           493641
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 0   2509.0  6995.0  38916.0    3472.0  ...     5802.0  43005.0  12172.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0    544.0   15625.0     34569.0         1413.0     5681.0   1886.0  254611
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2012.csv"
df2.to_csv(file_path, index=False)
