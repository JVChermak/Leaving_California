# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2017.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States2                321,994,428  +/- 33,543
# 1                 Alabama                  4,819,343   +/- 3,710
# 2                  Alaska                    730,874   +/- 1,438
# 3                 Arizona                  6,935,358   +/- 3,888
# 4                Arkansas                  2,968,395   +/- 3,103
#
#   Same residence 1 year ago        MOE.1  \
# 0               275,921,008  +/- 183,767
# 1                 4,158,224   +/- 20,321
# 2                   595,804    +/- 9,147
# 3                 5,717,189   +/- 24,333
# 4                 2,509,717   +/- 16,654
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 36,468,599  +/- 171,943
# 1                                    535,649   +/- 18,004
# 2                                     98,168    +/- 8,242
# 3                                    911,120   +/- 22,690
# 4                                    370,309   +/- 15,515
#
#   Different state of residence 1 year ago       MOE.3  Alabama  ... Wyoming  \
# 0                               7,471,493  +/- 70,316  101,466  ...  25,954
# 1                                 111,803   +/- 8,786      NaN  ...     104
# 2                                  30,199   +/- 4,584      942  ...       6
# 3                                 261,727  +/- 11,986    1,337  ...     997
# 4                                  79,411   +/- 7,492      574  ...      12
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 4,190  2,133,328  +/- 38,070      97,488  +/- 9,821           18,321
# 1    +/- 193     13,667   +/- 2,273         476    +/- 469                0
# 2     +/- 13      6,703   +/- 2,197           0    +/- 153              965
# 3    +/- 910     45,322   +/- 5,364         438    +/- 358               91
# 4     +/- 25      8,958   +/- 2,034         573    +/- 602                0
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 3,416       2,017,519  +/- 36,251
# 1    +/- 200          13,191   +/- 2,200
# 2    +/- 797           5,738   +/- 2,168
# 3    +/- 106          44,793   +/- 5,315
# 4    +/- 201           8,385   +/- 1,955
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 1 null values
# Column MOE.56 has 1 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States2  321,994,428  275,921,008  36,468,599       7,471,493
# 1         Alabama    4,819,343    4,158,224     535,649         111,803
# 2          Alaska      730,874      595,804      98,168          30,199
# 3         Arizona    6,935,358    5,717,189     911,120         261,727
# 4        Arkansas    2,968,395    2,509,717     370,309          79,411
#
#    Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  101,466  42,972  163,214   69,850    661,026  ...   155,665  467,338
# 1      NaN     424    1,513      517      2,328  ...     8,018    8,825
# 2      942     NaN    1,387      203      3,556  ...       544    2,165
# 3    1,337   2,255      NaN    1,763     59,233  ...     2,194   12,793
# 4      574     241    1,060      NaN      5,334  ...     5,383   15,767
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  89,721  20,872  262,563    198,813        43,321   113,492  25,954
# 1     998       0    4,277      1,289         1,070     1,121     104
# 2     465       0      360      3,653             0     2,500       6
# 3   8,594      96    3,593     14,392           318     3,897     997
# 4     657       0    1,087      1,539             0       958      12
#
#        Total
# 0  2,133,328
# 1     13,667
# 2      6,703
# 3     45,322
# 4      8,958
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2017)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2017         United States2  321,994,428  275,921,008  36,468,599
# 1   2017                Alabama    4,819,343    4,158,224     535,649
# 2   2017                 Alaska      730,874      595,804      98,168
# 3   2017                Arizona    6,935,358    5,717,189     911,120
# 4   2017               Arkansas    2,968,395    2,509,717     370,309
# 5   2017             California   39,085,984   34,009,331   4,234,770
# 6   2017               Colorado    5,542,282    4,546,729     734,182
# 7   2017            Connecticut    3,556,297    3,136,666     311,726
# 8   2017               Delaware      952,449      830,905      78,998
# 9   2017  District of Columbia       684,810      554,225      64,013
# 10  2017                Florida   20,772,371   17,554,348   2,402,381
# 11  2017                Georgia   10,299,497    8,760,762   1,202,587
# 12  2017                 Hawaii    1,410,750    1,231,340     115,683
# 13  2017                  Idaho    1,694,182    1,405,344     210,310
# 14  2017               Illinois   12,659,328   11,026,895   1,365,922
# 15  2017                Indiana    6,591,598    5,633,171     792,487
# 16  2017                   Iowa    3,106,880    2,654,666     362,905
# 17  2017                 Kansas    2,876,925    2,413,141     366,147
# 18  2017               Kentucky    4,404,279    3,721,100     563,721
# 19  2017              Louisiana    4,629,962    4,030,674     513,676
# 20  2017                  Maine    1,322,591    1,140,136     144,186
# 21  2017               Maryland    5,988,007    5,168,350     605,885
# 22  2017          Massachusetts    6,789,798    5,888,011     677,835
# 23  2017               Michigan    9,851,330    8,450,559   1,203,536
# 24  2017              Minnesota    5,510,902    4,728,748     643,272
# 25  2017            Mississippi    2,946,971    2,553,271     313,673
# 26  2017               Missouri    6,039,877    5,108,238     742,205
# 27  2017                Montana    1,039,170      883,342     116,400
# 28  2017               Nebraska    1,894,217    1,586,729     243,792
# 29  2017                 Nevada    2,963,456    2,430,163     383,067
# 30  2017          New Hampshire    1,330,742    1,134,244     137,212
# 31  2017             New Jersey    8,910,191    7,968,039     710,807
# 32  2017             New Mexico    2,062,628    1,801,560     193,225
# 33  2017               New York   19,638,923   17,553,033   1,655,152
# 34  2017         North Carolina   10,158,556    8,649,400   1,139,260
# 35  2017           North Dakota      744,641      609,017      92,436
# 36  2017                   Ohio   11,520,109    9,822,847   1,452,745
# 37  2017               Oklahoma    3,875,922    3,216,306     542,724
# 38  2017                 Oregon    4,102,048    3,405,784     520,747
# 39  2017           Pennsylvania   12,674,642   11,072,942   1,292,389
# 40  2017           Rhode Island    1,048,549      922,210      83,440
# 41  2017         South Carolina    4,966,211    4,248,517     531,315
# 42  2017           South Dakota      856,726      723,740      99,781
# 43  2017              Tennessee    6,642,072    5,675,990     748,912
# 44  2017                  Texas   27,924,632   23,534,387   3,643,333
# 45  2017                   Utah    3,056,193    2,532,858     398,606
# 46  2017                Vermont      619,089      536,390      57,588
# 47  2017               Virginia    8,372,522    7,089,782     958,267
# 48  2017             Washington    7,318,811    6,016,482     978,057
# 49  2017          West Virginia    1,798,306    1,589,833     165,375
#
#    Different state  Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        7,471,493  101,466  42,972  163,214   69,850  ...   155,665  467,338
# 1          111,803      NaN     424    1,513      517  ...     8,018    8,825
# 2           30,199      942     NaN    1,387      203  ...       544    2,165
# 3          261,727    1,337   2,255      NaN    1,763  ...     2,194   12,793
# 4           79,411      574     241    1,060      NaN  ...     5,383   15,767
# 5          523,131    3,715   2,606   26,907    3,471  ...     5,413   40,999
# 6          226,933    3,120   2,030    6,765    1,356  ...     2,453   25,212
# 7           83,325      206     540      644      160  ...       166    3,698
# 8           38,532      506       0       76        0  ...       318    1,152
# 9           56,231      494       0      549      105  ...     1,057    2,858
# 10         566,476    9,389   1,400    5,577    3,028  ...    12,023   31,625
# 11         278,889   15,270     986    6,218    2,055  ...    15,224   19,969
# 12          46,457      844     424    1,666       48  ...       495    4,078
# 13          71,899       58     796    1,523      265  ...       749    3,685
# 14         195,092    1,682     270    4,159    2,591  ...     5,086   11,642
# 15         142,290    1,216     131      948      852  ...     5,122   10,543
# 16          77,072      817     629    2,346      693  ...     1,152    3,315
# 17          86,154      276     515    1,404    1,225  ...       788    9,814
# 18         103,985    2,851     506      333      342  ...    11,642    6,677
# 19          72,836    2,830     199      520    3,289  ...     1,733   17,674
# 20          34,252      246     163      322       12  ...       255      491
# 21         165,654      644     961    1,689      410  ...       977    6,890
# 22         146,299      212     539    1,030      207  ...       957    4,603
# 23         148,787    3,669     348    4,948      825  ...     3,703    7,033
# 24         115,623      491     671    2,587      634  ...     2,212    5,529
# 25          73,549    5,936     127      553    2,251  ...    11,636    5,056
# 26         164,957    2,518   1,224    2,820    6,560  ...     2,320   14,820
# 27          35,456      301     701      386      899  ...        87    1,569
# 28          52,507      420     199    1,456      267  ...       684    4,876
# 29         133,074      191   1,024    5,508      551  ...     1,022    5,346
# 30          52,893      109     151      190      185  ...       167    1,200
# 31         152,106      169     610      898      175  ...       715    6,591
# 32          57,255      770   1,470    7,129      258  ...       431   16,356
# 33         285,252    1,849   1,049    3,826    1,209  ...     4,072   10,058
# 34         313,834    4,526   1,401    5,624      747  ...     8,416   14,655
# 35          37,315       53     152      564       48  ...       478    1,678
# 36         198,929    2,487      79    3,143      683  ...     6,127   12,108
# 37         101,961    1,133   1,004    1,931    6,835  ...     2,337   32,430
# 38         149,513      179   2,808    6,938      526  ...     1,115    7,049
# 39         250,120    1,416     294    3,266      292  ...     2,249    7,226
# 40          36,850      135     109      101      175  ...       295      980
# 41         166,573    2,133       0    2,380      232  ...     4,263    9,001
# 42          26,106      144     183      402       83  ...       264    1,156
# 43         191,909    9,523     417    2,522    5,843  ...       NaN   12,904
# 44         524,511   10,235   3,543   14,875   14,222  ...    11,630      NaN
# 45          99,584      644     660    8,144      177  ...       972    6,536
# 46          21,868        0     203      132        0  ...       179      485
# 47         250,490    2,341     736    2,587    1,184  ...     4,121   15,596
# 48         260,787    1,605   7,532   11,733    1,074  ...     1,295   14,096
# 49          40,007      239     121       13        0  ...     1,266    2,175
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   89,721  20,872  262,563    198,813        43,321   113,492  25,954
# 1      998       0    4,277      1,289         1,070     1,121     104
# 2      465       0      360      3,653             0     2,500       6
# 3    8,594      96    3,593     14,392           318     3,897     997
# 4      657       0    1,087      1,539             0       958      12
# 5    9,925     895   21,162     33,143           789     9,348   1,395
# 6    3,417     471    6,099      6,675            42     3,506   5,135
# 7      149     393    1,314        374             0       188     257
# 8       32      59    1,510          0           371       296       0
# 9      384     447    7,509        206             0       115       0
# 10   6,063   2,816   28,232      6,176         2,187     7,202     396
# 11   1,503      38   11,256      2,649           420     3,504     630
# 12     962       0    2,656      2,837             0       213      96
# 13   7,226       0      612      8,881             0       442   1,747
# 14   1,160      51    4,127      4,846           130    12,274     414
# 15   1,240     512    1,867      2,782         1,044     3,757       0
# 16     489     227      774      1,405           550     3,011      54
# 17     981       0    1,029        801             0       317     123
# 18       0      85    2,453      1,428         2,140     1,599     266
# 19      34       0    2,073        623           261       319     195
# 20     444     569    1,162        336            72         0       0
# 21     810     386   23,315      1,839         3,926       901      44
# 22   1,335   2,000    3,083      1,672           161     1,098       0
# 23   1,250     330    3,539      1,572           392     3,485     635
# 24     392      46    1,552      3,333            44    20,555     213
# 25       0       0      286        888         1,158       402     212
# 26     760     228    2,795      3,120            90     3,784     529
# 27     879      31      683      3,879           112       497   4,072
# 28   1,467      13      774        351           164       694     572
# 29   4,410     237    1,147      5,203             0       381     143
# 30      30   1,874      460        146             0        97       0
# 31     269     274    5,750      1,135           329     1,013     110
# 32     411       0    1,694        563             0       274     267
# 33     334   2,929   10,677      5,529           402     1,269      54
# 34     623     524   27,833      5,896         3,423     1,895     159
# 35     247       0      434      1,362             0       861     829
# 36   2,100     364    5,224      2,960         7,343     2,011     248
# 37     204      37      921      2,018             0       509     251
# 38   4,103     308    3,566     26,150           257     1,370     227
# 39   1,182   1,853    8,417      3,199         4,128     1,696       0
# 40     211      93    1,643      1,215             0       233       0
# 41     842      14    8,778      1,420         3,111     1,627       0
# 42     170       0      364        195             0       974     728
# 43     652     235   11,339      1,789           996     1,426     362
# 44   9,131     662   15,436     14,646         1,353     7,443     948
# 45     NaN     204    3,187      5,270           142     1,064   1,722
# 46     130     NaN      636        181            48       106     643
# 47   2,123     963      NaN      5,488         5,294       961     305
# 48   7,603     503    7,976        NaN           547     2,106     581
# 49     456       0    5,388        469           NaN       173       0
#
#         Total
# 0   2,133,328
# 1      13,667
# 2       6,703
# 3      45,322
# 4       8,958
# 5     318,752
# 6      34,438
# 7      24,580
# 8       4,014
# 9      10,341
# 10    249,166
# 11     57,259
# 12     17,270
# 13      6,629
# 14     71,419
# 15     23,650
# 16     12,237
# 17     11,483
# 18     15,473
# 19     12,776
# 20      4,017
# 21     48,118
# 22     77,653
# 23     48,448
# 24     23,259
# 25      6,478
# 26     24,477
# 27      3,972
# 28     11,189
# 29     17,152
# 30      6,393
# 31     79,239
# 32     10,588
# 33    145,486
# 34     56,062
# 35      5,873
# 36     45,588
# 37     14,931
# 38     26,004
# 39     59,191
# 40      6,049
# 41     19,806
# 42      7,099
# 43     25,261
# 44    222,401
# 45     25,145
# 46      3,243
# 47     73,983
# 48     63,485
# 49      3,091
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2017  United States2   321994428   275921008    36468599          7471493
# 1  2017         Alabama     4819343     4158224      535649           111803
# 2  2017          Alaska      730874      595804       98168            30199
# 3  2017         Arizona     6935358     5717189      911120           261727
# 4  2017        Arkansas     2968395     2509717      370309            79411
#
#     Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  101466.0  42972.0  163214.0   69850.0  ...   155665.0  467338.0  89721.0
# 1       NaN    424.0    1513.0     517.0  ...     8018.0    8825.0    998.0
# 2     942.0      NaN    1387.0     203.0  ...      544.0    2165.0    465.0
# 3    1337.0   2255.0       NaN    1763.0  ...     2194.0   12793.0   8594.0
# 4     574.0    241.0    1060.0       NaN  ...     5383.0   15767.0    657.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  20872.0  262563.0    198813.0        43321.0   113492.0  25954.0  2133328
# 1      0.0    4277.0      1289.0         1070.0     1121.0    104.0    13667
# 2      0.0     360.0      3653.0            0.0     2500.0      6.0     6703
# 3     96.0    3593.0     14392.0          318.0     3897.0    997.0    45322
# 4      0.0    1087.0      1539.0            0.0      958.0     12.0     8958
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2017  California    39085984    34009331     4234770           523131
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 5   3715.0  2606.0  26907.0    3471.0  ...     5413.0  40999.0  9925.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5    895.0   21162.0     33143.0          789.0     9348.0   1395.0  318752
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2017  California    39085984    34009331     4234770           523131
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 0   3715.0  2606.0  26907.0    3471.0  ...     5413.0  40999.0  9925.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0    895.0   21162.0     33143.0          789.0     9348.0   1395.0  318752
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2017.csv"
df2.to_csv(file_path, index=False)
