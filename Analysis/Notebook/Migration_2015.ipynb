# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2015.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States2                317,635,720  +/- 28,922
# 1                 Alabama                  4,801,599   +/- 3,420
# 2                  Alaska                    727,862   +/- 1,356
# 3                 Arizona                  6,747,595   +/- 4,243
# 4                Arkansas                  2,938,341   +/- 3,200
#
#   Same residence 1 year ago        MOE.1  \
# 0               270,873,397  +/- 189,370
# 1                 4,113,945   +/- 22,379
# 2                   582,909    +/- 9,527
# 3                 5,536,087   +/- 26,178
# 4                 2,440,359   +/- 17,443
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 37,146,496  +/- 176,254
# 1                                    561,019   +/- 21,500
# 2                                    105,769    +/- 8,533
# 3                                    910,911   +/- 24,238
# 4                                    407,352   +/- 17,073
#
#   Different state of residence 1 year ago       MOE.3  Alabama  ... Wyoming  \
# 0                               7,530,129  +/- 67,868  100,809  ...  31,537
# 1                                 114,876   +/- 8,513      NaN  ...     164
# 2                                  34,696   +/- 4,503      279  ...     414
# 3                                 253,281  +/- 12,395      607  ...   2,473
# 4                                  81,594   +/- 7,126      956  ...     275
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 4,780  2,085,698  +/- 39,419      89,000  +/- 8,853           20,482
# 1    +/- 266     11,759   +/- 2,403          51    +/- 102                0
# 2    +/- 422      4,488   +/- 1,282          34     +/- 62               16
# 3  +/- 1,694     47,316   +/- 5,688       1,556  +/- 1,296              105
# 4    +/- 251      9,036   +/- 2,094           0    +/- 190                0
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 5,276       1,976,216  +/- 37,433
# 1    +/- 192          11,708   +/- 2,403
# 2     +/- 28           4,438   +/- 1,285
# 3    +/- 121          45,655   +/- 5,434
# 4    +/- 190           9,036   +/- 2,094
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 0 null values
# Column MOE.56 has 0 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States2  317,635,720  270,873,397  37,146,496       7,530,129
# 1         Alabama    4,801,599    4,113,945     561,019         114,876
# 2          Alaska      727,862      582,909     105,769          34,696
# 3         Arizona    6,747,595    5,536,087     910,911         253,281
# 4        Arkansas    2,938,341    2,440,359     407,352          81,594
#
#    Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  100,809  40,552  184,476   76,673    643,710  ...   176,961  445,343
# 1      NaN     767    1,865    2,329      3,397  ...     7,206    6,469
# 2      279     NaN      658       73      3,062  ...       133    2,196
# 3      607   2,519      NaN      553     54,646  ...     3,253   13,025
# 4      956     205    1,683      NaN      5,075  ...     6,033   17,708
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  84,071  22,135  268,593    178,528        51,953   109,243  31,537
# 1     362     173    4,772        871           445       491     164
# 2     337      53      521      3,988             0       161     414
# 3  10,165     406    3,801     14,183             0     5,262   2,473
# 4     445      36    2,355        313           143     1,312     275
#
#        Total
# 0  2,085,698
# 1     11,759
# 2      4,488
# 3     47,316
# 4      9,036
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2015)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2015         United States2  317,635,720  270,873,397  37,146,496
# 1   2015                Alabama    4,801,599    4,113,945     561,019
# 2   2015                 Alaska      727,862      582,909     105,769
# 3   2015                Arizona    6,747,595    5,536,087     910,911
# 4   2015               Arkansas    2,938,341    2,440,359     407,352
# 5   2015             California   38,675,135   33,446,324   4,377,667
# 6   2015               Colorado    5,393,067    4,404,058     728,077
# 7   2015            Connecticut    3,554,844    3,109,580     340,126
# 8   2015               Delaware      935,813      800,701      86,009
# 9   2015  District of Columbia       663,006      525,024      67,188
# 10  2015                Florida   20,068,392   16,832,374   2,438,828
# 11  2015                Georgia   10,088,525    8,489,689   1,259,007
# 12  2015                 Hawaii    1,414,355    1,206,066     136,796
# 13  2015                  Idaho    1,635,366    1,333,758     218,791
# 14  2015               Illinois   12,706,393   11,029,917   1,399,829
# 15  2015                Indiana    6,540,691    5,527,512     843,210
# 16  2015                   Iowa    3,081,446    2,598,298     386,465
# 17  2015                 Kansas    2,875,640    2,405,677     360,715
# 18  2015               Kentucky    4,373,403    3,706,705     543,811
# 19  2015              Louisiana    4,612,024    4,007,364     496,223
# 20  2015                  Maine    1,317,444    1,127,394     156,271
# 21  2015               Maryland    5,934,005    5,076,791     638,788
# 22  2015          Massachusetts    6,725,678    5,893,936     634,359
# 23  2015               Michigan    9,811,416    8,394,658   1,229,302
# 24  2015              Minnesota    5,419,822    4,618,325     661,383
# 25  2015            Mississippi    2,959,289    2,554,660     327,854
# 26  2015               Missouri    6,015,580    5,056,661     777,061
# 27  2015                Montana    1,019,646      855,861     118,200
# 28  2015               Nebraska    1,869,217    1,570,592     236,217
# 29  2015                 Nevada    2,859,489    2,291,842     413,831
# 30  2015          New Hampshire    1,318,121    1,134,482     122,442
# 31  2015             New Jersey    8,854,363    7,987,859     656,570
# 32  2015             New Mexico    2,060,441    1,767,704     228,103
# 33  2015               New York   19,570,171   17,506,652   1,653,268
# 34  2015         North Carolina    9,927,547    8,376,304   1,194,157
# 35  2015           North Dakota      745,291      608,377      90,498
# 36  2015                   Ohio   11,482,142    9,719,944   1,508,889
# 37  2015               Oklahoma    3,864,908    3,202,689     532,976
# 38  2015                 Oregon    3,985,712    3,277,453     544,776
# 39  2015           Pennsylvania   12,662,192   11,109,753   1,258,572
# 40  2015           Rhode Island    1,045,062      901,338      97,722
# 41  2015         South Carolina    4,839,984    4,106,166     543,488
# 42  2015           South Dakota      848,285      702,122     116,343
# 43  2015              Tennessee    6,522,259    5,535,963     766,524
# 44  2015                  Texas   27,092,848   22,723,345   3,594,282
# 45  2015                   Utah    2,947,423    2,435,722     390,649
# 46  2015                Vermont      619,952      532,319      62,067
# 47  2015               Virginia    8,283,737    6,952,362     983,569
# 48  2015             Washington    7,089,143    5,778,806   1,017,221
# 49  2015          West Virginia    1,823,753    1,610,407     167,631
#
#    Different state  Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        7,530,129  100,809  40,552  184,476   76,673  ...   176,961  445,343
# 1          114,876      NaN     767    1,865    2,329  ...     7,206    6,469
# 2           34,696      279     NaN      658       73  ...       133    2,196
# 3          253,281      607   2,519      NaN      553  ...     3,253   13,025
# 4           81,594      956     205    1,683      NaN  ...     6,033   17,708
# 5          514,477    5,273   6,022   34,204    2,867  ...     8,781   41,713
# 6          227,445    2,392   1,653   10,254    1,527  ...     2,314   25,268
# 7           76,997      163      68      187        0  ...       237    2,519
# 8           44,495       76     344      282        0  ...        82    1,423
# 9           59,905      359     235      367      203  ...       873    1,314
# 10         584,938   15,449   1,553    7,168    6,850  ...    19,864   29,706
# 11         283,325   16,372     669    1,713    1,668  ...    18,087   16,078
# 12          53,742      240     164    2,701      194  ...       331    2,031
# 13          73,809      564   1,061    3,152    1,441  ...       419    2,959
# 14         209,828    1,853     350    6,776    1,452  ...     5,566   11,719
# 15         147,529    2,130       0    2,871      640  ...     3,491    5,878
# 16          85,937      285     734    3,069    1,926  ...     1,747    4,325
# 17          91,340      717     201    2,079    1,504  ...     1,928    7,577
# 18         106,918    1,463     237      772      516  ...    12,533    5,595
# 19          93,321    3,318     101      279    2,993  ...     2,957   19,863
# 20          30,123        0      32      256        0  ...       220    1,817
# 21         168,894    1,526     361    2,649       54  ...     1,634    5,611
# 22         132,642      269     459    2,110      576  ...       316    4,398
# 23         142,639    1,387   1,701    4,007      992  ...     4,846    8,466
# 24         108,476      105     363    3,978      405  ...     1,773    4,814
# 25          69,351    6,827     474      337    1,497  ...     9,494    8,842
# 26         159,152    1,449     920    3,305    7,887  ...     2,940    9,634
# 27          42,760        0     657    1,187      320  ...       179    3,235
# 28          52,950       32     122    1,489      741  ...       478    4,460
# 29         135,999    1,830   1,017    5,598       50  ...       123    5,271
# 30          53,446      125       0      669        0  ...         0    1,407
# 31         144,074      250     839    1,521      243  ...       869    4,778
# 32          55,753      356     278    3,441       42  ...       660   12,101
# 33         257,611      850   1,020    5,993    1,054  ...     2,562   12,082
# 34         310,612    3,733     578    5,963      707  ...     7,575   15,245
# 35          42,618        0     196    1,008      255  ...       420    3,968
# 36         203,475    2,038   1,330    4,257    1,404  ...     5,162   11,553
# 37         110,878      957     278    2,495    6,881  ...     1,293   28,642
# 38         141,162      654   1,617    6,349      631  ...     1,190    4,761
# 39         232,683    1,663     368    2,921      765  ...     1,979    7,490
# 40          38,344       39      93      647        0  ...       908    1,164
# 41         170,366    1,854     250      900    1,612  ...     5,542    5,987
# 42          26,962       14     289    1,240      486  ...       404    1,742
# 43         195,923   10,291     624    2,513    6,071  ...       NaN   11,934
# 44         553,032    7,167   2,573   16,067   14,539  ...    13,199      NaN
# 45          97,361      369   1,630    7,650      230  ...     1,122    8,698
# 46          21,232      245      17       69        0  ...       435      144
# 47         277,715    2,888   1,221    2,181      856  ...     9,637   16,685
# 48         230,907      580   3,911    9,860    1,146  ...     2,794   12,829
# 49          42,078      240       0        0        7  ...       968      967
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   84,071  22,135  268,593    178,528        51,953   109,243  31,537
# 1      362     173    4,772        871           445       491     164
# 2      337      53      521      3,988             0       161     414
# 3   10,165     406    3,801     14,183             0     5,262   2,473
# 4      445      36    2,355        313           143     1,312     275
# 5    8,814     766   15,009     33,131           413     6,741   1,672
# 6    4,064   1,094    7,686      7,368         1,232     5,916   3,275
# 7       95     262    2,301      1,236            63       223       0
# 8       32      78    2,112        420           119         0       0
# 9      177     117    8,028        134           478       514       0
# 10   1,932   1,480   23,377      3,819         3,479     9,195     924
# 11   1,523     157   15,852      2,377         1,300     3,352     879
# 12   1,707       0    3,402      3,176           130       158       0
# 13   6,625     343      689      6,499           441       122   2,282
# 14     607     302    5,804      3,377           808    11,785     287
# 15     709     168    2,886      1,210            29     3,193     172
# 16      77      95      834      2,086            45     3,140     229
# 17   1,767       0    1,053      1,548           160       189     393
# 18     327       0    2,015      1,668         3,349       590     525
# 19     180       0    1,732      1,486            90       322      26
# 20     159     769      480        429            35       189     208
# 21     318     174   24,293      1,561         2,605     1,183     272
# 22     405   3,046    3,444      1,828           286       827       0
# 23     555     189    2,836      1,951           885     5,136     157
# 24   1,100      12    4,014      2,404            34    18,934     728
# 25      70       0    1,794      1,589           725       754      31
# 26     955       0    1,867      2,611           498     1,932     599
# 27   1,807      15      331      4,959            50       251   2,009
# 28     801       8    1,003        785             0     1,341     746
# 29   5,845       0    1,932      6,513           280     1,144     543
# 30       0   3,233    1,039          0            28       204       0
# 31      36     204    3,124      1,152           457       240     206
# 32   1,452     128    2,350      1,435           129       120     444
# 33   1,451   3,118    8,333      3,942         1,083     1,781     320
# 34   1,278     691   31,390      1,883         3,387     1,217     582
# 35     168       0      121      1,675           199       660     234
# 36     602     110    8,655      2,601         9,059     1,977      37
# 37   1,020     203    1,686      1,457           641       924     150
# 38   1,649     442    2,329     25,055           106     1,591   1,021
# 39   2,073     785   11,249      1,056         5,173     1,731     674
# 40     427      78      356        636            27         0       0
# 41   1,243     388    8,736        751         1,498     1,222       0
# 42     591       0      358        126             0       532   1,426
# 43   1,097   1,397    6,382        485         1,044     1,480     179
# 44   6,583     395   18,429      9,155         2,083     4,393   2,743
# 45     NaN     193    1,628      5,426           138     1,798   2,609
# 46     175     NaN      274        636             0         0      15
# 47   1,763     680      NaN      4,134         7,673     1,645     267
# 48   5,827     180    5,901        NaN         1,098     2,860     755
# 49     483     147    7,400        223           NaN        94       0
#
#         Total
# 0   2,085,698
# 1      11,759
# 2       4,488
# 3      47,316
# 4       9,036
# 5     336,667
# 6      33,487
# 7      28,141
# 8       4,608
# 9      10,889
# 10    212,252
# 11     56,504
# 12     17,751
# 13      9,008
# 14     66,819
# 15     22,440
# 16     10,746
# 17     17,908
# 18     15,969
# 19     15,116
# 20      3,656
# 21     49,532
# 22     64,741
# 23     44,817
# 24     31,638
# 25      7,424
# 26     22,706
# 27      2,825
# 28      9,458
# 29     17,817
# 30      7,751
# 31     65,860
# 32      8,881
# 33    152,640
# 34     46,474
# 35      3,798
# 36     49,834
# 37     18,365
# 38     22,321
# 39     61,184
# 40      7,658
# 41     19,964
# 42      2,858
# 43     23,849
# 44    222,189
# 45     23,691
# 46      4,334
# 47     70,091
# 48     62,209
# 49      3,637
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2015  United States2   317635720   270873397    37146496          7530129
# 1  2015         Alabama     4801599     4113945      561019           114876
# 2  2015          Alaska      727862      582909      105769            34696
# 3  2015         Arizona     6747595     5536087      910911           253281
# 4  2015        Arkansas     2938341     2440359      407352            81594
#
#     Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  100809.0  40552.0  184476.0   76673.0  ...   176961.0  445343.0  84071.0
# 1       NaN    767.0    1865.0    2329.0  ...     7206.0    6469.0    362.0
# 2     279.0      NaN     658.0      73.0  ...      133.0    2196.0    337.0
# 3     607.0   2519.0       NaN     553.0  ...     3253.0   13025.0  10165.0
# 4     956.0    205.0    1683.0       NaN  ...     6033.0   17708.0    445.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  22135.0  268593.0    178528.0        51953.0   109243.0  31537.0  2085698
# 1    173.0    4772.0       871.0          445.0      491.0    164.0    11759
# 2     53.0     521.0      3988.0            0.0      161.0    414.0     4488
# 3    406.0    3801.0     14183.0            0.0     5262.0   2473.0    47316
# 4     36.0    2355.0       313.0          143.0     1312.0    275.0     9036
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2015  California    38675135    33446324     4377667           514477
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 5   5273.0  6022.0  34204.0    2867.0  ...     8781.0  41713.0  8814.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5    766.0   15009.0     33131.0          413.0     6741.0   1672.0  336667
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2015  California    38675135    33446324     4377667           514477
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 0   5273.0  6022.0  34204.0    2867.0  ...     8781.0  41713.0  8814.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0    766.0   15009.0     33131.0          413.0     6741.0   1672.0  336667
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2015.csv"
df2.to_csv(file_path, index=False)
