# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2016.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States2                319,361,956  +/- 30,974
# 1                 Alabama                  4,810,126   +/- 3,913
# 2                  Alaska                    731,760   +/- 1,282
# 3                 Arizona                  6,851,836   +/- 4,173
# 4                Arkansas                  2,949,650   +/- 3,135
#
#   Same residence 1 year ago        MOE.1  \
# 0               272,660,098  +/- 208,903
# 1                 4,141,850   +/- 18,249
# 2                   593,897    +/- 7,921
# 3                 5,586,753   +/- 30,225
# 4                 2,484,705   +/- 17,957
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 36,952,658  +/- 198,593
# 1                                    529,994   +/- 17,409
# 2                                    100,004    +/- 6,403
# 3                                    938,077   +/- 26,500
# 4                                    384,811   +/- 15,832
#
#   Different state of residence 1 year ago       MOE.3 Alabama  ... Wyoming  \
# 0                               7,552,536  +/- 73,712  99,892  ...  27,184
# 1                                 122,220   +/- 9,811     NaN  ...     539
# 2                                  31,300   +/- 3,641     423  ...     291
# 3                                 273,257  +/- 14,805     894  ...     925
# 4                                  71,083   +/- 6,657   2,057  ...     178
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 3,871  2,196,664  +/- 37,386      88,676  +/- 7,958           16,060
# 1    +/- 691     16,062   +/- 2,720         335    +/- 214              608
# 2    +/- 242      6,559   +/- 1,959         848  +/- 1,059              350
# 3    +/- 683     53,749   +/- 6,106       1,462    +/- 917              151
# 4    +/- 290      9,051   +/- 1,843         857    +/- 794                0
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 2,338       2,091,928  +/- 36,976
# 1    +/- 479          15,119   +/- 2,741
# 2    +/- 448           5,361   +/- 1,639
# 3    +/- 253          52,136   +/- 6,088
# 4    +/- 197           8,194   +/- 1,794
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 1 null values
# Column MOE.56 has 1 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States2  319,361,956  272,660,098  36,952,658       7,552,536
# 1         Alabama    4,810,126    4,141,850     529,994         122,220
# 2          Alaska      731,760      593,897     100,004          31,300
# 3         Arizona    6,851,836    5,586,753     938,077         273,257
# 4        Arkansas    2,949,650    2,484,705     384,811          71,083
#
#   Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  99,892  42,074  192,103   72,033    657,690  ...   182,813  444,340
# 1     NaN     576    1,022      495      6,611  ...     9,960    7,689
# 2     423     NaN    1,176       65      3,593  ...       243    1,675
# 3     894   1,946      NaN    1,205     64,756  ...     1,834   14,923
# 4   2,057     103      836      NaN      4,026  ...     2,635   13,487
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  85,803  23,693  275,671    192,362        51,476   113,882  27,184
# 1     525       0    3,535        677            42       874     539
# 2     725      86      462      4,888             0       260     291
# 3   9,979     817    8,809     13,897         1,419     6,736     925
# 4     619       0    1,333      2,257            75       539     178
#
#        Total
# 0  2,196,664
# 1     16,062
# 2      6,559
# 3     53,749
# 4      9,051
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2016)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2016         United States2  319,361,956  272,660,098  36,952,658
# 1   2016                Alabama    4,810,126    4,141,850     529,994
# 2   2016                 Alaska      731,760      593,897     100,004
# 3   2016                Arizona    6,851,836    5,586,753     938,077
# 4   2016               Arkansas    2,949,650    2,484,705     384,811
# 5   2016             California   38,783,436   33,594,813   4,337,251
# 6   2016               Colorado    5,476,928    4,466,067     754,712
# 7   2016            Connecticut    3,541,758    3,116,440     323,316
# 8   2016               Delaware      942,073      817,779      85,147
# 9   2016  District of Columbia       672,022      538,547      64,166
# 10  2016                Florida   20,401,575   17,176,492   2,387,227
# 11  2016                Georgia   10,179,860    8,514,847   1,290,632
# 12  2016                 Hawaii    1,410,258    1,217,704     117,894
# 13  2016                  Idaho    1,663,756    1,369,449     214,222
# 14  2016               Illinois   12,654,142   10,996,695   1,387,848
# 15  2016                Indiana    6,554,084    5,580,090     801,425
# 16  2016                   Iowa    3,097,283    2,622,577     383,520
# 17  2016                 Kansas    2,870,529    2,394,351     369,971
# 18  2016               Kentucky    4,385,213    3,698,797     553,718
# 19  2016              Louisiana    4,622,042    3,994,321     526,380
# 20  2016                  Maine    1,319,292    1,146,220     129,892
# 21  2016               Maryland    5,949,566    5,140,378     606,423
# 22  2016          Massachusetts    6,745,441    5,866,016     657,022
# 23  2016               Michigan    9,813,772    8,362,412   1,240,633
# 24  2016              Minnesota    5,455,904    4,669,227     645,164
# 25  2016            Mississippi    2,951,081    2,556,013     324,577
# 26  2016               Missouri    6,022,165    5,078,669     758,791
# 27  2016                Montana    1,032,794      863,174     128,300
# 28  2016               Nebraska    1,882,987    1,573,126     248,118
# 29  2016                 Nevada    2,907,243    2,400,809     374,058
# 30  2016          New Hampshire    1,322,101    1,122,068     140,603
# 31  2016             New Jersey    8,852,286    7,934,689     703,637
# 32  2016             New Mexico    2,057,857    1,768,040     214,411
# 33  2016               New York   19,526,443   17,465,164   1,634,487
# 34  2016         North Carolina   10,032,407    8,460,264   1,190,972
# 35  2016           North Dakota      746,271      620,891      91,010
# 36  2016                   Ohio   11,481,752    9,755,589   1,482,286
# 37  2016               Oklahoma    3,873,232    3,225,478     530,770
# 38  2016                 Oregon    4,052,221    3,307,805     577,950
# 39  2016           Pennsylvania   12,645,493   11,016,361   1,308,271
# 40  2016           Rhode Island    1,045,691      898,574     106,725
# 41  2016         South Carolina    4,903,788    4,176,954     542,415
# 42  2016           South Dakota      853,832      720,262      97,747
# 43  2016              Tennessee    6,580,953    5,644,022     742,615
# 44  2016                  Texas   27,472,626   23,105,984   3,599,897
# 45  2016                   Utah    3,002,244    2,474,308     396,018
# 46  2016                Vermont      619,387      535,268      60,744
# 47  2016               Virginia    8,312,297    7,008,805     961,003
# 48  2016             Washington    7,202,119    5,924,723     958,326
# 49  2016          West Virginia    1,810,709    1,582,818     176,953
#
#    Different state Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        7,552,536  99,892  42,074  192,103   72,033  ...   182,813  444,340
# 1          122,220     NaN     576    1,022      495  ...     9,960    7,689
# 2           31,300     423     NaN    1,176       65  ...       243    1,675
# 3          273,257     894   1,946      NaN    1,205  ...     1,834   14,923
# 4           71,083   2,057     103      836      NaN  ...     2,635   13,487
# 5          514,758   3,045   4,206   33,757    4,282  ...     6,158   39,109
# 6          223,260   2,328   1,698   13,015      808  ...     4,035   20,725
# 7           75,586   1,102     331      309      960  ...       394    2,679
# 8           33,400     148      80       22        0  ...        34      515
# 9           58,154     140      77      744        0  ...       452    2,213
# 10         605,018  11,353   1,852   10,312    4,136  ...    18,647   31,153
# 11         305,040  18,276   1,287    3,901    2,388  ...    20,161   19,994
# 12          57,229   1,182     672    1,852      155  ...     1,582    4,485
# 13          71,556       0   1,638    4,322      341  ...        60    2,606
# 14         203,713   2,022     578    5,251    1,288  ...     6,928   13,290
# 15         145,782   1,133     495    1,185    1,308  ...     2,979    9,403
# 16          78,263     395     662    1,556      315  ...     1,256    3,437
# 17          88,830     879     291    2,664    1,526  ...     1,754   10,102
# 18         113,238   2,272     361    1,177      756  ...    12,132    5,585
# 19          85,371   5,658     359      857    1,471  ...     2,184   21,925
# 20          38,590     471       7      257        0  ...       461      610
# 21         158,647   1,241      53      940      349  ...     2,288    5,229
# 22         149,408     681     115    2,511      388  ...       780    3,446
# 23         155,874   2,287     285    4,061      806  ...     5,154   10,484
# 24         111,307     115     334    4,475      484  ...     1,393    4,849
# 25          64,639   5,125       0      544    3,244  ...    10,017    4,046
# 26         162,809   2,283   1,288    2,958    8,523  ...     4,026   11,488
# 27          37,775     296     608    1,416      340  ...       138    2,177
# 28          51,448     227     549    1,264      568  ...       270    2,702
# 29         117,899     394     562    5,741      534  ...     1,189    3,343
# 30          52,457     174     740      678        0  ...        95    1,527
# 31         144,359      48     299    1,013      137  ...     1,608    5,554
# 32          64,802     732     749    7,350      552  ...     1,723   17,155
# 33         260,723     402     421    4,971      755  ...     3,661    9,368
# 34         330,896   3,491   2,059    3,539    1,135  ...     8,233   11,981
# 35          29,655     193     151      681      144  ...       177    1,378
# 36         195,396   3,101     169    2,620      873  ...     7,805    8,712
# 37         102,000     176     328    1,912    7,396  ...     1,309   28,060
# 38         139,334     167     549    4,932      921  ...     1,168    5,377
# 39         252,060   1,978     820    2,076      979  ...     2,746   12,497
# 40          32,800      53       0      360       91  ...       581    1,079
# 41         165,230   2,823     411    1,708      581  ...     3,709    7,373
# 42          31,789       0     346      732       18  ...       147    1,946
# 43         170,867   7,683   1,141    1,449    5,583  ...       NaN   11,827
# 44         531,996   6,915   2,257   20,322   11,986  ...    15,565      NaN
# 45         107,083     125   2,350    9,140    1,136  ...       964    7,467
# 46          21,262       0       0      337        0  ...         6        7
# 47         264,164   2,424   1,624    3,584      519  ...     7,491   15,873
# 48         257,728   1,465   5,374   12,801      823  ...     3,672   16,005
# 49          47,196     284      11       57      195  ...     1,903    1,345
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   85,803  23,693  275,671    192,362        51,476   113,882  27,184
# 1      525       0    3,535        677            42       874     539
# 2      725      86      462      4,888             0       260     291
# 3    9,979     817    8,809     13,897         1,419     6,736     925
# 4      619       0    1,333      2,257            75       539     178
# 5   11,114     400   14,348     27,973         1,150     7,354   2,674
# 6    3,642     647    7,148      4,487           309     3,243   3,657
# 7        0   1,131    2,320        631           286       237       0
# 8        0     112    1,021        181           158         0       0
# 9      249       0    9,847        418           296       242       0
# 10   3,531   1,627   29,485      6,152         3,979    11,298     454
# 11     923     730   11,597      3,270           838     1,273      22
# 12     589      83    2,033      4,355            20        54       0
# 13   7,405       0      401      9,303           122       249   3,030
# 14   1,211     919    7,822      3,628           880    15,595     271
# 15     254     119    3,188      1,203           156     2,460       0
# 16     496     137      663      1,662           203     3,848     171
# 17     845      71    1,812      1,885             0       125      79
# 18     874       0    3,145        313         2,929     1,313       0
# 19     280     122    2,548      1,516           586       714     162
# 20     589     661    1,276        907           107       328       0
# 21     387     347   23,926      2,176         4,744       723       0
# 22     524   3,226    4,166      1,463           292     1,484     166
# 23     718     424    1,989      1,849           435     5,058   1,380
# 24   1,828      40    1,071      2,666           331    18,683     846
# 25      48       0    1,230      1,989           260     1,455       0
# 26   1,272      61    2,918      2,916           514     1,828     540
# 27   1,343     114        0      5,132           110       939   1,434
# 28   1,064       0      935        812            45       223   1,281
# 29   3,260      37    1,307      4,639            14       889   1,686
# 30     613   2,789      696         11           297        84       0
# 31     104     360    5,341        534           350       330       0
# 32     625       0      801      1,843           153       332     198
# 33   1,068   3,895   10,761      4,929         1,503     2,787      83
# 34   1,271     608   35,641      4,751         3,722     2,600     145
# 35      38       0      251        709           144       556     342
# 36   1,622     435    5,844      3,423         8,726     1,660     179
# 37     783      61    1,312      1,658           174       829     299
# 38   3,246     158    2,141     24,207           140       557     563
# 39   2,014     604   12,785      3,772         3,979     2,337     188
# 40      60     337      714        399             0       325       0
# 41     424       0    8,081      1,943         2,403     1,243     508
# 42     662       0      720        976           131     1,026   2,047
# 43     181     309    6,681      2,187         1,249     1,309      25
# 44   9,082     252   19,660     14,335           915     4,927     732
# 45     NaN     221    1,392      5,074            51       398     755
# 46      77     NaN      242        165            23        54       0
# 47   1,507     872      NaN      4,925         6,618     1,877      48
# 48   5,404     743    3,834        NaN           319     1,940     866
# 49     179       0    6,114        216           NaN         0       0
#
#         Total
# 0   2,196,664
# 1      16,062
# 2       6,559
# 3      53,749
# 4       9,051
# 5     336,614
# 6      32,889
# 7      26,416
# 8       5,747
# 9      11,155
# 10    232,838
# 11     69,341
# 12     17,431
# 13      8,529
# 14     65,886
# 15     26,787
# 16     12,923
# 17     17,377
# 18     19,460
# 19     15,970
# 20      4,590
# 21     44,118
# 22     72,995
# 23     54,853
# 24     30,206
# 25      5,852
# 26     21,896
# 27      3,545
# 28     10,295
# 29     14,477
# 30      6,973
# 31     69,601
# 32     10,604
# 33    166,069
# 34     50,275
# 35      4,715
# 36     48,481
# 37     14,984
# 38     27,132
# 39     68,801
# 40      7,592
# 41     19,189
# 42      4,034
# 43     23,449
# 44    234,749
# 45     24,835
# 46      2,113
# 47     78,325
# 48     61,342
# 49      3,742
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2016  United States2   319361956   272660098    36952658          7552536
# 1  2016         Alabama     4810126     4141850      529994           122220
# 2  2016          Alaska      731760      593897      100004            31300
# 3  2016         Arizona     6851836     5586753      938077           273257
# 4  2016        Arkansas     2949650     2484705      384811            71083
#
#    Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  99892.0  42074.0  192103.0   72033.0  ...   182813.0  444340.0  85803.0
# 1      NaN    576.0    1022.0     495.0  ...     9960.0    7689.0    525.0
# 2    423.0      NaN    1176.0      65.0  ...      243.0    1675.0    725.0
# 3    894.0   1946.0       NaN    1205.0  ...     1834.0   14923.0   9979.0
# 4   2057.0    103.0     836.0       NaN  ...     2635.0   13487.0    619.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  23693.0  275671.0    192362.0        51476.0   113882.0  27184.0  2196664
# 1      0.0    3535.0       677.0           42.0      874.0    539.0    16062
# 2     86.0     462.0      4888.0            0.0      260.0    291.0     6559
# 3    817.0    8809.0     13897.0         1419.0     6736.0    925.0    53749
# 4      0.0    1333.0      2257.0           75.0      539.0    178.0     9051
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2016  California    38783436    33594813     4337251           514758
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 5   3045.0  4206.0  33757.0    4282.0  ...     6158.0  39109.0  11114.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5    400.0   14348.0     27973.0         1150.0     7354.0   2674.0  336614
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2016  California    38783436    33594813     4337251           514758
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 0   3045.0  4206.0  33757.0    4282.0  ...     6158.0  39109.0  11114.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0    400.0   14348.0     27973.0         1150.0     7354.0   2674.0  336614
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2016.csv"
df2.to_csv(file_path, index=False)
