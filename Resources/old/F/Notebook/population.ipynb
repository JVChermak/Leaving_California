# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/flow_data/pop_data.csv")
df
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
# List row and column counts
df.shape
# Out:
# (57, 151)

# %%
# List dataframe data types
df.dtypes
# Out:
# SUMLEV           int64
# REGION          object
# DIVISION        object
# STATE            int64
# NAME            object
#                 ...
# RNETMIG2015    float64
# RNETMIG2016    float64
# RNETMIG2017    float64
# RNETMIG2018    float64
# RNETMIG2019    float64
# Length: 151, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column SUMLEV has 0 null values
# Column REGION has 0 null values
# Column DIVISION has 0 null values
# Column STATE has 0 null values
# Column NAME has 0 null values
# Column CENSUS2010POP has 0 null values
# Column ESTIMATESBASE2010 has 0 null values
# Column POPESTIMATE2010 has 0 null values
# Column POPESTIMATE2011 has 0 null values
# Column POPESTIMATE2012 has 0 null values
# Column POPESTIMATE2013 has 0 null values
# Column POPESTIMATE2014 has 0 null values
# Column POPESTIMATE2015 has 0 null values
# Column POPESTIMATE2016 has 0 null values
# Column POPESTIMATE2017 has 0 null values
# Column POPESTIMATE2018 has 0 null values
# Column POPESTIMATE2019 has 0 null values
# Column NPOPCHG_2010 has 0 null values
# Column NPOPCHG_2011 has 0 null values
# Column NPOPCHG_2012 has 0 null values
# Column NPOPCHG_2013 has 0 null values
# Column NPOPCHG_2014 has 0 null values
# Column NPOPCHG_2015 has 0 null values
# Column NPOPCHG_2016 has 0 null values
# ...

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# Only view needed column information
pop = df.filter(items=['REGION', 'NAME', 'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017', 'POPESTIMATE2018', 'NPOPCHG_2010', 'NPOPCHG_2011', 'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015', 'NPOPCHG_2016', 'NPOPCHG_2017', 'NPOPCHG_2018', 'NETMIG2010', 'NETMIG2011', 'NETMIG2012', 'NETMIG2013', 'NETMIG2014', 'NETMIG2015', 'NETMIG2016', 'NETMIG2017', 'NETMIG2018', 'RNETMIG2010', 'RNETMIG2011', 'RNETMIG2012', 'RNETMIG2013', 'RNETMIG2014', 'RNETMIG2015', 'RNETMIG2016', 'RNETMIG2017', 'RNETMIG2018'])
pop
# Out:
#    REGION                  NAME  POPESTIMATE2010  POPESTIMATE2011  \
# 0       0         United States        309321666        311556874
# 1       1      Northeast Region         55380134         55604223
# 2       2        Midwest Region         66974416         67157800
# 3       3          South Region        114866680        116006522
# 4       4           West Region         72100436         72788329
# 5       3               Alabama          4785437          4799069
# 6       4                Alaska           713910           722128
# 7       4               Arizona          6407172          6472643
# 8       3              Arkansas          2921964          2940667
# 9       4            California         37319502         37638369
# 10      4              Colorado          5047349          5121108
# 11      1           Connecticut          3579114          3588283
# 12      3              Delaware           899593           907381
# ...

# %%
# Change column names
pop.rename(columns={'REGION': 'Region', 'NAME': 'NAME', 'POPESTIMATE2010': 'Population 2010', 'POPESTIMATE2011': 'Population 2011', 'POPESTIMATE2012': 'Population 2012', 'POPESTIMATE2013': 'Population 2013', 'POPESTIMATE2014': 'Population 2014', 'POPESTIMATE2015': 'Population 2015', 'POPESTIMATE2016': 'Population 2016', 'POPESTIMATE2017': 'Population 2017', 'POPESTIMATE2018': 'Population 2018', 'NPOPCHG_2010': 'Net Pop Chg 2010', 'NPOPCHG_2011': 'Net Pop Chg 2011', 'NPOPCHG_2012': 'Net Pop Chg 2012', 'NPOPCHG_2013': 'Net Pop Chg 2013', 'NPOPCHG_2014': 'Net Pop Chg 2014', 'NPOPCHG_2015': 'Net Pop Chg 2015', 'NPOPCHG_2016': 'Net Pop Chg 2016', 'NPOPCHG_2017': 'Net Pop Chg 2017', 'NPOPCHG_2018': 'Net Pop Chg 2018', 'NETMIG2010': 'Net Migration 2010', 'NETMIG2011': 'Net Migration 2011', 'NETMIG2012': 'Net Migration 2012', 'NETMIG2013': 'Net Migration 2013', 'NETMIG2014': 'Net Migration 2014', 'NETMIG2015': 'Net Migration 2015', 'NETMIG2016': 'Net Migration 2016', 'NETMIG2017': 'Net Migration 2017', 'NETMIG2018': 'Net Migration 2018', 'RNETMIG2010': '%Net Migration 2010', 'RNETMIG2011': '%Net Migration 2011', 'RNETMIG2012': '%Net Migration 2012', 'RNETMIG2013': '%Net Migration 2013', 'RNETMIG2014': '%Net Migration 2014', 'RNETMIG2015': '%Net Migration 2015', 'RNETMIG2016': '%Net Migration 2016', 'RNETMIG2017': '%Net Migration 2017', 'RNETMIG2018': '%Net Migration 2018'}, inplace=True)
pop.head()
# Out:
#   Region              NAME  Population 2010  Population 2011  Population 2012  \
# 0      0     United States        309321666        311556874        313830990
# 1      1  Northeast Region         55380134         55604223         55775216
# 2      2    Midwest Region         66974416         67157800         67336743
# 3      3      South Region        114866680        116006522        117241208
# 4      4       West Region         72100436         72788329         73477823
#
#    Population 2013  Population 2014  Population 2015  Population 2016  \
# 0        315993715        318301008        320635163        322941311
# 1         55901806         56006011         56034684         56042330
# 2         67560379         67745167         67860583         67987540
# 3        118364400        119624037        120997341        122351760
# 4         74167130         74925793         75742555         76559681
#
#    Population 2017  ...  Net Migration 2017  Net Migration 2018  \
# ...

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
pop.dtypes
# Out:
# Region                  object
# NAME                    object
# Population 2010          int64
# Population 2011          int64
# Population 2012          int64
# Population 2013          int64
# Population 2014          int64
# Population 2015          int64
# Population 2016          int64
# Population 2017          int64
# Population 2018          int64
# Net Pop Chg 2010         int64
# Net Pop Chg 2011         int64
# Net Pop Chg 2012         int64
# Net Pop Chg 2013         int64
# Net Pop Chg 2014         int64
# Net Pop Chg 2015         int64
# Net Pop Chg 2016         int64
# Net Pop Chg 2017         int64
# Net Pop Chg 2018         int64
# Net Migration 2010       int64
# Net Migration 2011       int64
# Net Migration 2012       int64
# Net Migration 2013       int64
# Net Migration 2014       int64
# Net Migration 2015       int64
# Net Migration 2016       int64
# Net Migration 2017       int64
# Net Migration 2018       int64
# %Net Migration 2011    float64
# ...

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/population_data.csv"
pop.to_csv(file_path, index=False)
