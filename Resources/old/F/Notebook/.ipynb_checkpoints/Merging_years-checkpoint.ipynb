# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df_2010 = pd.read_csv("../Resources/clean_data/2010.csv")
df_2010.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2010     Alabama                   9.1                      23.6
# 1  2010      Alaska                   2.0                       2.9
# 2  2010     Arizona                   4.0                      13.4
# 3  2010    Arkansas                  12.0                      27.0
# 4  2010  California                   1.5                       3.4
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        20.3                        17.8
# 1                         9.6                        15.6
# 2                        20.5                        19.5
# 3                        23.9                        16.2
# 4                         6.0                         8.6
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.8                         8.7
# 1                        35.2                        26.5
# ...

# %%
# Read in our data
df_2011 = pd.read_csv("../Resources/clean_data/2011.csv")
df_2011.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2011     Alabama                   8.7                      22.4
# 1  2011      Alaska                   2.0                       2.9
# 2  2011     Arizona                   5.2                      18.0
# 3  2011    Arkansas                  11.0                      29.6
# 4  2011  California                   1.6                       3.8
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        22.2                        18.5
# 1                         6.2                        17.6
# 2                        21.7                        18.0
# 3                        22.0                        16.0
# 4                         7.0                         9.0
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.2                         8.7
# 1                        36.3                        27.7
# ...

# %%
# Read in our data
df_2012 = pd.read_csv("../Resources/clean_data/2012.csv")
df_2012.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2012     Alabama                   8.5                      23.0
# 1  2012      Alaska                   2.3                       2.7
# 2  2012     Arizona                   5.7                      18.3
# 3  2012    Arkansas                  11.0                      28.7
# 4  2012  California                   1.7                       4.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        21.7                        17.9
# 1                         7.4                        14.3
# 2                        21.9                        17.0
# 3                        22.6                        16.1
# 4                         7.2                         9.3
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.8                         9.0
# 1                        38.1                        28.9
# ...

# %%
# Read in our data
df_2013 = pd.read_csv("../Resources/clean_data/2013.csv")
df_2013.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2013     Alabama                   9.0                      22.2
# 1  2013      Alaska                   1.9                       2.5
# 2  2013     Arizona                   5.4                      13.2
# 3  2013    Arkansas                  11.3                      26.7
# 4  2013  California                   2.8                       3.2
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        22.3                        17.4
# 1                         6.5                        15.4
# 2                        19.4                        18.5
# 3                        23.8                        16.2
# 4                         5.7                         8.0
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.7                         9.3
# 1                        36.4                        30.4
# ...

# %%
# Read in our data
df_2014 = pd.read_csv("../Resources/clean_data/2014.csv")
df_2014.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2014     Alabama                   8.8                      21.6
# 1  2014      Alaska                   2.6                       2.5
# 2  2014     Arizona                   4.9                      11.0
# 3  2014    Arkansas                  10.4                      26.2
# 4  2014  California                   2.7                       2.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        21.5                        17.2
# 1                         5.7                        15.4
# 2                        16.7                        19.0
# 3                        23.4                        17.2
# 4                         4.1                         6.2
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        18.2                         9.7
# 1                        35.6                        30.9
# ...

# %%
# Read in our data
df_2015 = pd.read_csv("../Resources/clean_data/2015.csv")
df_2015.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2015     Alabama                   6.5                      21.6
# 1  2015      Alaska                   1.5                       2.3
# 2  2015     Arizona                   2.7                       9.1
# 3  2015    Arkansas                   7.7                      23.9
# 4  2015  California                   1.1                       1.7
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        57.3                        10.7
# 1                        54.6                        33.0
# 2                        60.0                        19.2
# 3                        57.1                         7.9
# 4                        22.2                        30.5
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         2.5                         0.8
# 1                         6.7                         1.4
# ...

# %%
# Read in our data
df_2016 = pd.read_csv("../Resources/clean_data/2016.csv")
df_2016.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2016     Alabama                   6.6                      19.7
# 1  2016      Alaska                   2.0                       2.4
# 2  2016     Arizona                   2.6                       7.4
# 3  2016    Arkansas                   7.3                      23.3
# 4  2016  California                   1.1                       1.4
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        58.8                        11.0
# 1                        49.7                        36.0
# 2                        60.0                        21.2
# 3                        57.8                         8.6
# 4                        19.4                        29.4
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         2.4                         0.9
# 1                         7.7                         1.5
# ...

# %%
# Read in our data
df_2017 = pd.read_csv("../Resources/clean_data/2017.csv")
df_2017.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2017     Alabama                 45154                    134584
# 1  2017      Alaska                  2324                      1966
# 2  2017     Arizona                 25820                     58155
# 3  2017    Arkansas                 29303                     92956
# 4  2017  California                 48868                     55518
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                      413329                       81925
# 1                       51086                       37285
# 2                      618612                      253759
# 3                      246125                       36118
# 4                      834760                     1430771
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                       21023                        5464
# 1                        7595                        1480
# ...

# %%
# Read in our data
df_2018 = pd.read_csv("../Resources/clean_data/2018.csv")
df_2018.head()
# Out:
#    Year            NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2018          Alaska                  1301                      2485
# 1  2018           Maine                  8347                     22503
# 2  2018  North Carolina                 46822                    189660
# 3  2018        Missouri                 48211                    152276
# 4  2018    Pennsylvania                 69616                    246255
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                       50283                       37611
# 1                      154319                       46623
# 2                      943652                      308264
# 3                      598632                      135389
# 4                     1196823                      397957
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        8472                        1817
# 1                       10248                        2816
# ...

# %%
# Combine all the dfs
df = pd.concat([df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018], sort=True)
df
# Out:
#     2nd Mortgage Only (%)  2nd Mortgage or Equity Loan (%)  \
# 0                     4.9                             17.2
# 1                     4.5                             14.9
# 2                     5.8                             21.8
# 3                     4.1                             10.5
# 4                     7.6                             26.3
# ..                    ...                              ...
# 47                58290.0                         303356.0
# 48                25030.0                         199591.0
# 49                 3043.0                          14236.0
# 50                18174.0                          72368.0
# 51                36035.0                         325392.0
#
#     Both 2nd & Equity Loan (%)  Equity Loan Only (%)  \
# 0                          0.6                  12.3
# 1                          0.7                  10.4
# 2                          0.8                  16.0
# ...

# %%
# Reset the index
df.reset_index(drop=True, inplace=True)
df
# Out:
#      2nd Mortgage Only (%)  2nd Mortgage or Equity Loan (%)  \
# 0                      4.9                             17.2
# 1                      4.5                             14.9
# 2                      5.8                             21.8
# 3                      4.1                             10.5
# 4                      7.6                             26.3
# ..                     ...                              ...
# 463                58290.0                         303356.0
# 464                25030.0                         199591.0
# 465                 3043.0                          14236.0
# 466                18174.0                          72368.0
# 467                36035.0                         325392.0
#
#      Both 2nd & Equity Loan (%)  Equity Loan Only (%)  \
# 0                           0.6                  12.3
# 1                           0.7                  10.4
# 2                           0.8                  16.0
# ...

# %%
# list column names
cols = list(df.columns.values)

# %%
cols
# Out:
# ['2nd Mortgage Only (%)',
#  '2nd Mortgage or Equity Loan (%)',
#  'Both 2nd & Equity Loan (%)',
#  'Equity Loan Only (%)',
#  'Home Value $100k-$149k (%)',
#  'Home Value $150k-$199k (%)',
#  'Home Value $200k-$299k (%)',
#  'Home Value $300k-$499k (%)',
#  'Home Value $500k+ (%)',
#  'Home Value $50k-$90k (%)',
#  'Home Value <$50k (%)',
#  'Income $100k-$149,999 (%)',
#  'Income $10k-$24,999 (%)',
#  'Income $150k+ (%)',
#  'Income $25k-$34,999 (%)',
#  'Income $35k-$49,999 (%)',
#  'Income $50k-$74,999 (%)',
#  'Income $75k-$99,999 (%)',
#  'Income <$10k (%)',
#  'Median Home Value ($)(1000X)',
#  'Median Housing Cost (monthly) ($)',
#  'Median Income ($)(1000X)',
#  'Median Real Estate Taxes ($)',
#  'NAME',
#  'Net Migration',
#  'Net Migration Change',
#  'Net Population Change',
#  'No 2nd or Equity Loan (%)',
#  'Population',
#  'Region',
#  'Year']

# %%
# Re-order columns
df = df[['Year', 
         'Region', 
         'NAME',  
         'Home Value <$50k (%)',
         'Home Value $50k-$90k (%)', 
         'Home Value $100k-$149k (%)',
         'Home Value $150k-$199k (%)', 
         'Home Value $200k-$299k (%)', 
         'Home Value $300k-$499k (%)', 
         'Home Value $500k+ (%)', 
         'Median Home Value ($)(1000X)', 
         'Median Housing Cost (monthly) ($)',
         'Income <$10k (%)',
         'Income $10k-$24,999 (%)',
         'Income $25k-$34,999 (%)', 
         'Income $35k-$49,999 (%)', 
         'Income $50k-$74,999 (%)', 
         'Income $75k-$99,999 (%)', 
         'Income $100k-$149,999 (%)',
         'Income $150k+ (%)', 
         'Median Income ($)(1000X)', 
         'Median Real Estate Taxes ($)', 
         'No 2nd or Equity Loan (%)',
         '2nd Mortgage or Equity Loan (%)',
         'Equity Loan Only (%)',
         '2nd Mortgage Only (%)',
         'Both 2nd & Equity Loan (%)',
         'Population', 
         'Net Population Change', 
         'Net Migration', 
         'Net Migration Change']]

# %%
df.head()
# Out:
#    Year Region        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2010      3     Alabama                   9.1                      23.6
# 1  2010      4      Alaska                   2.0                       2.9
# 2  2010      4     Arizona                   4.0                      13.4
# 3  2010      3    Arkansas                  12.0                      27.0
# 4  2010      4  California                   1.5                       3.4
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        20.3                        17.8
# 1                         9.6                        15.6
# 2                        20.5                        19.5
# 3                        23.9                        16.2
# 4                         6.0                         8.6
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.8                         8.7
# ...

# %%
# Saving cleaned data
file_path = "../Resources/data_ready_to_train/US_data.csv"
df.to_csv(file_path, index=False)
