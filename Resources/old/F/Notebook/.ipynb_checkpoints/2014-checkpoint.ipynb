# %%
# Import our dependencies
import pandas as pd
import numpy as np

# %%
# Read in our data
census = pd.read_csv("../Resources/clean_data/census_2014.csv")

# %%
# Read in our data
pop = pd.read_csv("../Resources/clean_data/pop_2014.csv")

# %%
# Change column names
census.rename(columns={'State': 'NAME'}, inplace=True)

# %%
df = pd.merge(census, pop, on='NAME', how='left').fillna(method='ffill')

# %%
# Change column names
df.rename(columns={'Year_x': 'Year'}, inplace=True)

# %%
# Delete Year_y column 
del df['Year_y']

# %%
df.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2014     Alabama                   8.8                      21.6
# 1  2014      Alaska                   2.6                       2.5
# 2  2014     Arizona                   4.9                      11.0
# 3  2014    Arkansas                  10.4                      26.2
# 4  2014  California                   2.7                       2.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        21.5                        17.2
# 1                         5.7                        15.4
# 2                        16.7                        19.0
# 3                        23.4                        17.2
# 4                         4.1                         6.2
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        18.2                         9.7
# 1                        35.6                        30.9
# 2                        22.4                        17.7
# 3                        13.6                         6.9
# 4                        14.7                        30.0
#
#    Home Value $500k+ (%)  Median Home Value ($)(1000X)  ...  \
# 0                    3.0                         145.7  ...
# 1                    7.4                         268.7  ...
# 2                    8.3                         194.9  ...
# 3                    2.4                         128.2  ...
# 4                   40.2                         427.7  ...
#
#    Income $100k-$149,999 (%)  Income $150k+ (%)  Median Income ($)(1000X)  \
# 0                       18.0               10.5                    66.546
# 1                       28.6               23.4                   102.659
# 2                       18.6               14.6                    72.609
# 3                       16.5                9.2                    63.705
# 4                       21.8               26.4                    96.305
#
#    Median Housing Cost (monthly) ($)  Median Real Estate Taxes ($)  Region  \
# 0                               1119                           603       3
# 1                               1797                          3260       4
# 2                               1273                          1401       4
# 3                                995                           835       3
# 4                               2068                          3548       4
#
#    Population  Net Population Change  Net Migration  Net Migration Change
# 0     4841799                  11718           2725              0.563489
# 1      736283                   -785          -8443            -11.460949
# 2     6730413                  97649          61260              9.168478
# 3     2967392                   7992           -271             -0.091449
# 4    38596972                 336185          84680              2.203551
#
# [5 rows x 31 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/2014.csv"
df.to_csv(file_path, index=False)
