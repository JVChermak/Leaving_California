# %%
# Import our dependencies
import pandas as pd
import numpy as np

# %%
# Read in our data
census = pd.read_csv("../Resources/clean_data/census_2015.csv")

# %%
# Read in our data
pop = pd.read_csv("../Resources/clean_data/pop_2015.csv")

# %%
# Change column names
census.rename(columns={'State': 'NAME'}, inplace=True)

# %%
df = pd.merge(census, pop, on='NAME', how='left').fillna(method='ffill')

# %%
# Change column names
df.rename(columns={'Year_x': 'Year'}, inplace=True)

# %%
# Delete Year_y column 
del df['Year_y']

# %%
df.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2015     Alabama                   6.5                      21.6
# 1  2015      Alaska                   1.5                       2.3
# 2  2015     Arizona                   2.7                       9.1
# 3  2015    Arkansas                   7.7                      23.9
# 4  2015  California                   1.1                       1.7
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        57.3                        10.7
# 1                        54.6                        33.0
# 2                        60.0                        19.2
# 3                        57.1                         7.9
# 4                        22.2                        30.5
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         2.5                         0.8
# 1                         6.7                         1.4
# 2                         5.7                         1.7
# 3                         2.1                         0.7
# 4                        22.0                        10.7
#
#    Home Value $500k+ (%)  Median Home Value ($)(1000X)  ...  \
# 0                    0.6                         151.8  ...
# 1                    0.4                         276.1  ...
# 2                    1.5                         211.6  ...
# 3                    0.6                         135.9  ...
# 4                   11.9                         462.0  ...
#
#    Income $75k-$99,999 (%)  Income $100k-$149,999 (%)  Income $150k+ (%)  \
# 0                     16.3                       18.1               11.8
# 1                     16.7                       25.7               25.1
# 2                     16.1                       18.6               15.0
# 3                     15.5                       16.5               10.2
# 4                     14.5                       22.2               28.0
#
#    Median Income ($)(1000X)  Median Housing Cost (monthly) ($)  Region  \
# 0                    70.359                                0.1       3
# 1                   100.776                                0.0       4
# 2                    74.562                                0.1       4
# 3                    65.687                                0.2       3
# 4                   100.223                                0.0       4
#
#    Population  Net Population Change  Net Migration  Net Migration Change
# 0     4852347                  10548           3036              0.626357
# 1      737498                   1215          -5893             -7.997118
# 2     6829676                  99263          65072              9.597577
# 3     2978048                  10656           3197              1.075446
# 4    38918045                 321073          76932              1.984957
#
# [5 rows x 30 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/2015.csv"
df.to_csv(file_path, index=False)
