# %%
# Import our dependencies
import pandas as pd
import numpy as np

# %%
# Read in our data
census = pd.read_csv("../Resources/clean_data/census_2018.csv")

# %%
# Read in our data
pop = pd.read_csv("../Resources/clean_data/pop_2018.csv")

# %%
# Change column names
census.rename(columns={'State': 'NAME'}, inplace=True)

# %%
df = pd.merge(census, pop, on='NAME', how='left').fillna(method='ffill')

# %%
# Change column names
df.rename(columns={'Year_x': 'Year'}, inplace=True)

# %%
# Delete Year_y column 
del df['Year_y']

# %%
df.head()
# Out:
#    Year            NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2018          Alaska                  1301                      2485
# 1  2018           Maine                  8347                     22503
# 2  2018  North Carolina                 46822                    189660
# 3  2018        Missouri                 48211                    152276
# 4  2018    Pennsylvania                 69616                    246255
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                       50283                       37611
# 1                      154319                       46623
# 2                      943652                      308264
# 3                      598632                      135389
# 4                     1196823                      397957
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        8472                        1817
# 1                       10248                        2816
# 2                       86931                       28949
# 3                       34108                       10285
# 4                      114215                       29943
#
#    Home Value $500k+ (%)  Median Home Value ($)(1000X)  ...  \
# 0                    737                         292.6  ...
# 1                   2488                         208.3  ...
# 2                  19457                         199.6  ...
# 3                   7507                         170.8  ...
# 4                  21342                         202.0  ...
#
#    Income $75k-$99,999 (%)  Income $100k-$149,999 (%)  Income $150k+ (%)  \
# 0                    15589                      28377              27329
# 1                    45453                      54975              36498
# 2                   267775                     334621             291402
# 3                   168477                     212500             166676
# 4                   342305                     478432             440000
#
#    Median Income ($)(1000X)  Median Housing Cost (monthly) ($)  Region  \
# 0                   105.294                                 52       4
# 1                    81.392                                 10       1
# 2                    81.504                                708       3
# 3                    81.877                               2162       2
# 4                    90.755                               1042       1
#
#    Population  Net Population Change  Net Migration  Net Migration Change
# 0      735139                  -4561         -10220            -13.859140
# 1     1339057                   4445           6642              4.968453
# 2    10381615                 113382          86828              8.409553
# 3     6121623                  14953           3058              0.500152
# 4    12800922                  13281          10944              0.855382
#
# [5 rows x 30 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/2018.csv"
df.to_csv(file_path, index=False)
