# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/clean_data/population_data.csv")
df.head()
# Out:
#   Region              NAME  Population 2010  Population 2011  Population 2012  \
# 0      0     United States        309321666        311556874        313830990
# 1      1  Northeast Region         55380134         55604223         55775216
# 2      2    Midwest Region         66974416         67157800         67336743
# 3      3      South Region        114866680        116006522        117241208
# 4      4       West Region         72100436         72788329         73477823
#
#    Population 2013  Population 2014  Population 2015  Population 2016  \
# 0        315993715        318301008        320635163        322941311
# 1         55901806         56006011         56034684         56042330
# 2         67560379         67745167         67860583         67987540
# 3        118364400        119624037        120997341        122351760
# 4         74167130         74925793         75742555         76559681
#
#    Population 2017  ...  Net Migration 2017  Net Migration 2018  \
# ...

# %%
df.columns
# Out:
# Index(['Region', 'NAME', 'Population 2010', 'Population 2011',
#        'Population 2012', 'Population 2013', 'Population 2014',
#        'Population 2015', 'Population 2016', 'Population 2017',
#        'Population 2018', 'Net Pop Chg 2010', 'Net Pop Chg 2011',
#        'Net Pop Chg 2012', 'Net Pop Chg 2013', 'Net Pop Chg 2014',
#        'Net Pop Chg 2015', 'Net Pop Chg 2016', 'Net Pop Chg 2017',
#        'Net Pop Chg 2018', 'Net Migration 2010', 'Net Migration 2011',
#        'Net Migration 2012', 'Net Migration 2013', 'Net Migration 2014',
#        'Net Migration 2015', 'Net Migration 2016', 'Net Migration 2017',
#        'Net Migration 2018', '%Net Migration 2011', '%Net Migration 2012',
#        '%Net Migration 2013', '%Net Migration 2014', '%Net Migration 2015',
#        '%Net Migration 2016', '%Net Migration 2017', '%Net Migration 2018'],
#       dtype='object')

# %%
# Only view needed column information
pop = df.filter(items=['Region', 'NAME', 'Population 2012', 'Net Pop Chg 2012', 'Net Migration 2012', '%Net Migration 2012'])
pop.head()
# Out:
#    Region                  NAME  Population 2012  Net Pop Chg 2012  \
# 0       0         United States        313830990           2274116
# 1       1      Northeast Region         55775216            170993
# 2       2        Midwest Region         67336743            178943
# 3       3          South Region        117241208           1234686
# 4       4           West Region         73477823            689494
# 5       3               Alabama          4815588             16519
# 6       4                Alaska           730443              8315
# 7       4               Arizona          6554978             82335
# 8       3              Arkansas          2952164             11497
# 9       4            California         37948800            310431
# 10      4              Colorado          5192647             71539
# 11      1           Connecticut          3594547              6264
# 12      3              Delaware           915179              7798
# ...

# %%
# Adding 'Year' column
pop.insert(0, 'Year', 2012)
pop.head()
# Out:
#    Year Region              NAME  Population 2012  Net Pop Chg 2012  \
# 0  2012      0     United States        313830990           2274116
# 1  2012      1  Northeast Region         55775216            170993
# 2  2012      2    Midwest Region         67336743            178943
# 3  2012      3      South Region        117241208           1234686
# 4  2012      4       West Region         73477823            689494
#
#    Net Migration 2012  %Net Migration 2012
# 0              838671             2.682083
# 1               -2136            -0.038355
# 2              -65495            -0.973943
# 3              682303             5.850458
# 4              223999             3.062896

# %%
# Change column names
pop.rename(columns={'Population 2012': 'Population', 'Net Pop Chg 2012': 'Net Population Change', 'Net Migration 2012': 'Net Migration', '%Net Migration 2012': 'Net Migration Change'}, inplace=True)
pop.head()
# Out:
#    Year Region              NAME  Population  Net Population Change  \
# 0  2012      0     United States   313830990                2274116
# 1  2012      1  Northeast Region    55775216                 170993
# 2  2012      2    Midwest Region    67336743                 178943
# 3  2012      3      South Region   117241208                1234686
# 4  2012      4       West Region    73477823                 689494
#
#    Net Migration  Net Migration Change
# 0         838671              2.682083
# 1          -2136             -0.038355
# 2         -65495             -0.973943
# 3         682303              5.850458
# 4         223999              3.062896

# %%
pop.dtypes
# Out:
# Year                       int64
# Region                    object
# NAME                      object
# Population                 int64
# Net Population Change      int64
# Net Migration              int64
# Net Migration Change     float64
# dtype: object

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/pop_2012.csv"
pop.to_csv(file_path, index=False)
