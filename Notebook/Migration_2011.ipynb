# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2011.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States1                307,900,319  +/- 29,996
# 1                 Alabama                  4,745,278   +/- 4,078
# 2                  Alaska                    711,962   +/- 1,401
# 3                 Arizona                  6,402,301   +/- 5,660
# 4                Arkansas                  2,906,632   +/- 2,928
#
#   Same residence 1 year ago        MOE.1  \
# 0               261,087,925  +/- 263,315
# 1                 4,024,442   +/- 22,751
# 2                   571,857    +/- 8,892
# 3                 5,107,496   +/- 39,045
# 4                 2,421,746   +/- 18,606
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 37,998,701  +/- 233,440
# 1                                    588,293   +/- 20,366
# 2                                    100,280    +/- 8,388
# 3                                  1,028,366   +/- 36,556
# 4                                    405,831   +/- 18,050
#
#   Different state of residence 1 year ago       MOE.3  Alabama  ... Wyoming  \
# 0                               6,987,416  +/- 77,858  106,806  ...  31,991
# 1                                 117,726   +/- 9,414      NaN  ...       9
# 2                                  35,084   +/- 4,168       93  ...     246
# 3                                 222,877  +/- 14,358      833  ...   2,510
# 4                                  69,845   +/- 7,292      691  ...     252
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 4,631  1,826,277  +/- 39,657      76,218  +/- 8,799           13,131
# 1     +/- 15     14,817   +/- 2,811         569    +/- 601                0
# 2    +/- 272      4,741   +/- 1,264       1,044    +/- 962                0
# 3  +/- 1,288     43,562   +/- 6,373         871    +/- 639              122
# 4    +/- 399      9,210   +/- 3,170         529    +/- 507               46
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 3,168       1,736,928  +/- 37,914
# 1    +/- 190          14,248   +/- 2,893
# 2    +/- 149           3,697     +/- 901
# 3    +/- 135          42,569   +/- 6,259
# 4     +/- 81           8,635   +/- 3,062
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 0 null values
# Column MOE.56 has 0 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States1  307,900,319  261,087,925  37,998,701       6,987,416
# 1         Alabama    4,745,278    4,024,442     588,293         117,726
# 2          Alaska      711,962      571,857     100,280          35,084
# 3         Arizona    6,402,301    5,107,496   1,028,366         222,877
# 4        Arkansas    2,906,632    2,421,746     405,831          69,845
#
#    Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  106,806  88,850  211,816   77,226    562,343  ...   154,243  404,839
# 1      NaN   1,771    1,677    1,642      3,389  ...     8,710    7,973
# 2       93     NaN    2,467      190      3,098  ...       388    2,492
# 3      833   5,001      NaN    1,066     49,635  ...     1,680   12,688
# 4      691     560      439      NaN      4,077  ...     6,462   14,767
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  73,211  18,172  229,227    190,644        45,956   105,370  31,991
# 1     300      66    4,935      2,621            65       417       9
# 2     662      68    1,488      4,548            89        23     246
# 3  10,577       0    2,233     13,940            70     6,473   2,510
# 4       0       0    1,245      1,477            24       687     252
#
#        Total
# 0  1,826,277
# 1     14,817
# 2      4,741
# 3     43,562
# 4      9,210
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2011)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2011         United States1  307,900,319  261,087,925  37,998,701
# 1   2011                Alabama    4,745,278    4,024,442     588,293
# 2   2011                 Alaska      711,962      571,857     100,280
# 3   2011                Arizona    6,402,301    5,107,496   1,028,366
# 4   2011               Arkansas    2,906,632    2,421,746     405,831
# 5   2011             California   37,222,678   31,213,310   5,271,168
# 6   2011               Colorado    5,048,443    4,048,042     763,233
# 7   2011            Connecticut    3,548,667    3,139,496     316,883
# 8   2011               Delaware      897,187      775,414      83,156
# 9   2011  District of Columbia       611,608      489,659      66,519
# 10  2011                Florida   18,863,948   15,742,168   2,454,255
# 11  2011                Georgia    9,699,859    8,095,407   1,289,450
# 12  2011                 Hawaii    1,357,806    1,160,948     122,727
# 13  2011                  Idaho    1,559,637    1,284,530     208,434
# 14  2011               Illinois   12,718,402   11,076,528   1,353,853
# 15  2011                Indiana    6,437,155    5,478,683     809,158
# 16  2011                   Iowa    3,027,718    2,573,313     370,554
# 17  2011                 Kansas    2,833,584    2,372,033     362,782
# 18  2011               Kentucky    4,316,297    3,686,232     505,741
# 19  2011              Louisiana    4,518,629    3,865,118     538,691
# 20  2011                  Maine    1,315,833    1,120,364     157,102
# 21  2011               Maryland    5,759,087    5,008,452     553,895
# 22  2011          Massachusetts    6,515,057    5,658,768     656,441
# 23  2011               Michigan    9,766,574    8,340,767   1,242,917
# 24  2011              Minnesota    5,277,329    4,505,462     646,176
# 25  2011            Mississippi    2,943,021    2,534,036     332,934
# 26  2011               Missouri    5,937,896    4,963,040     801,046
# 27  2011                Montana      987,076      828,254     122,210
# 28  2011               Nebraska    1,817,126    1,505,191     253,269
# 29  2011                 Nevada    2,688,336    2,084,668     480,317
# 30  2011          New Hampshire    1,305,678    1,141,236     122,129
# 31  2011             New Jersey    8,719,952    7,825,661     693,380
# 32  2011             New Mexico    2,055,293    1,753,413     228,218
# 33  2011               New York   19,248,685   17,055,260   1,756,105
# 34  2011         North Carolina    9,539,412    8,070,238   1,160,510
# 35  2011           North Dakota      675,161      559,906      79,837
# 36  2011                   Ohio   11,418,944    9,764,366   1,425,709
# 37  2011               Oklahoma    3,742,698    3,089,041     528,498
# 38  2011                 Oregon    3,828,714    3,128,121     549,332
# 39  2011           Pennsylvania   12,610,486   11,099,077   1,224,564
# 40  2011           Rhode Island    1,040,022      903,786     101,689
# 41  2011         South Carolina    4,624,180    3,899,705     546,666
# 42  2011           South Dakota      814,175      688,436      94,655
# 43  2011              Tennessee    6,333,466    5,342,978     794,556
# 44  2011                  Texas   25,327,104   20,984,855   3,648,260
# 45  2011                   Utah    2,769,627    2,295,961     373,984
# 46  2011                Vermont      621,354      537,304      60,719
# 47  2011               Virginia    7,996,552    6,789,620     889,751
# 48  2011             Washington    6,748,474    5,565,069     919,925
# 49  2011          West Virginia    1,836,614    1,609,110     172,262
#
#    Different state  Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        6,987,416  106,806  88,850  211,816   77,226  ...   154,243  404,839
# 1          117,726      NaN   1,771    1,677    1,642  ...     8,710    7,973
# 2           35,084       93     NaN    2,467      190  ...       388    2,492
# 3          222,877      833   5,001      NaN    1,066  ...     1,680   12,688
# 4           69,845      691     560      439      NaN  ...     6,462   14,767
# 5          468,428    2,087   7,358   35,650    2,648  ...     8,761   37,087
# 6          202,124    2,340   3,191   12,338    1,615  ...     3,193   22,390
# 7           71,502      101     180    1,387       84  ...       123    1,214
# 8           33,912       81     329      541        0  ...       221      883
# 9           48,066       13     135       43       81  ...       421    1,083
# 10         498,597   12,635   7,405    8,451    3,025  ...    10,451   25,532
# 11         271,077   18,799   1,079    4,292    2,112  ...    16,898   15,760
# 12          57,542    1,268     844    2,900      242  ...       636    3,007
# 13          60,336      263   4,510    3,543      224  ...       296    1,303
# 14         216,204    2,823   4,119    7,657    3,185  ...     3,223   11,011
# 15         127,874    1,562     371    3,975    2,016  ...     3,879    6,326
# 16          70,405      207     967    1,411      433  ...       623    2,334
# 17          83,640      434     108    2,028      998  ...     1,066    6,575
# 18         110,031      925       0    1,818    1,058  ...    16,852    4,661
# 19          99,138    3,065     288    2,010    2,774  ...     2,495   30,292
# 20          33,818      634      37      325       38  ...       394    1,637
# 21         153,979      228     671      945      423  ...     1,942    3,619
# 22         139,830    1,201     225    1,017      167  ...       371    5,203
# 23         139,158    3,527   3,456    3,840    2,054  ...     3,106    9,935
# 24         101,029      123     893    2,314      951  ...       874    3,062
# 25          68,511    8,922     117      556    2,315  ...     7,683    5,243
# 26         149,439    1,395   2,043    2,356    6,168  ...     2,676   10,293
# 27          33,553      449   1,118    1,971       49  ...       266    1,329
# 28          52,070      169     721    1,646      161  ...       226    5,343
# 29         110,345      280     597   10,142      310  ...        96    7,249
# 30          37,000      193       0      246       22  ...       126      605
# 31         140,194      189   1,198    3,784       57  ...     1,412    3,801
# 32          62,130      410     416    7,444      682  ...       899   13,633
# 33         282,209    1,812   6,124    2,821    1,041  ...     2,660    9,151
# 34         265,291    5,420   3,991    4,286      327  ...     6,057    6,621
# 35          32,510       97     393    1,313      249  ...       113    1,862
# 36         191,778    1,567   1,637    6,763    1,952  ...     6,468   11,987
# 37         108,878      591   1,137    3,770    6,894  ...     1,700   31,595
# 38         127,906      758   1,935    7,911      988  ...       673    4,498
# 39         234,291    1,332     759    2,278      582  ...     3,742    7,006
# 40          26,769        0       0      214        0  ...       210      207
# 41         157,644    2,999   2,421    1,971    1,333  ...     3,324    8,623
# 42          27,506        0     554    1,422      659  ...         0    1,156
# 43         170,969    9,326     531    1,346    7,393  ...       NaN    7,009
# 44         514,726    8,747   6,670   20,073   16,461  ...    10,788      NaN
# 45          85,217      486   2,151    6,585      422  ...       549    4,507
# 46          20,463        0     580      310        0  ...       327      185
# 47         257,130    4,930   3,202    4,679      645  ...     7,482   11,655
# 48         208,507    1,821   5,266   12,397      756  ...     2,342   15,491
# 49          50,068      221     598       50      225  ...       546    1,574
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   73,211  18,172  229,227    190,644        45,956   105,370  31,991
# 1      300      66    4,935      2,621            65       417       9
# 2      662      68    1,488      4,548            89        23     246
# 3   10,577       0    2,233     13,940            70     6,473   2,510
# 4        0       0    1,245      1,477            24       687     252
# 5    8,944     745   15,753     36,481           832     5,668   2,047
# 6    3,856     914    6,281      5,524           412     3,995   2,942
# 7      398     608    2,555      2,255            46       660      65
# 8      475       0    1,064        482           198        55     463
# 9       75     445    7,975        476           120       946       0
# 10   2,343   2,019   16,614      6,339         4,964     7,412     846
# 11     793     361    9,438      3,701         1,340     2,727     504
# 12   1,040       0    2,523      3,790           312       147      14
# 13   6,059       0      905      8,991             0       165     487
# 14     951      49    5,233      3,075           352    14,507      58
# 15     123     530    1,486      1,028           216     2,923     117
# 16   1,482      38      720        856           115     2,537     140
# 17     196       0    1,986        772             0       893   1,285
# 18     140     151    5,154      1,121         1,174       581      57
# 19     179      87    2,055      1,075           110       339     357
# 20     182     612      570         88            43       321      21
# 21     223      40   22,089      1,525         2,027       353      80
# 22     548   2,246    2,984      1,673           911       441       0
# 23     642       0    2,327      1,430           417     4,018     841
# 24     919     177    1,034      1,413            92    19,255     224
# 25     332       0    1,453        286           303     1,136       0
# 26   1,697      88    2,684      2,518           196     1,503   1,120
# 27   1,232      53      278      3,835            14       146   2,413
# 28     734       0      615        835            24       560     965
# 29   3,365       0    1,740      4,680             0     2,672     933
# 30     158   2,138      880        428             0         0     162
# 31     256       0    4,458      2,454         1,252       214      15
# 32     303      71      425        924             0       340     283
# 33     773   3,882   10,800      2,986           631     1,878     688
# 34     961     212   27,302      3,295         2,780     2,291     153
# 35     429       0      166        404             0     1,398     139
# 36     691      68    5,425      1,979         7,548     2,534   1,280
# 37     587       0    1,013      1,246            44       942   1,763
# 38   3,443     176    1,179     21,862            66       914     914
# 39   1,246     446    8,419      3,688         4,631     2,426     195
# 40     181     621      485        262           199         2      23
# 41     181      91    7,879      2,510         1,680       341     632
# 42     560       0       79        557             0       481   1,310
# 43     200      38    6,098      2,852         1,385     1,213     131
# 44   5,234     349   13,231     15,325           663     5,982   2,500
# 45     NaN     122    2,413      4,825           270       158   1,058
# 46     182     NaN      740        156            53       137      38
# 47   1,426     173      NaN      4,615         9,041       858     190
# 48   4,789     119    4,233        NaN           157     1,491   1,507
# 49     114      23    5,561         83           NaN        42       0
#
#         Total
# 0   1,826,277
# 1      14,817
# 2       4,741
# 3      43,562
# 4       9,210
# 5     269,772
# 6      35,044
# 7      20,786
# 8       4,705
# 9       7,364
# 10    168,928
# 11     43,925
# 12     16,589
# 13      6,337
# 14     71,817
# 15     21,440
# 16     13,446
# 17     15,129
# 18     14,293
# 19     15,682
# 20      4,549
# 21     42,761
# 22     60,018
# 23     43,732
# 24     24,662
# 25      7,540
# 26     24,371
# 27      3,059
# 28      6,596
# 29     13,006
# 30      5,313
# 31     60,717
# 32     11,532
# 33    155,111
# 34     43,373
# 35      2,908
# 36     37,091
# 37     16,281
# 38     23,355
# 39     52,554
# 40      7,778
# 41     20,165
# 42      3,578
# 43     24,963
# 44    179,263
# 45     14,465
# 46      2,868
# 47     60,051
# 48     54,973
# 49      5,174
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2011  United States1   307900319   261087925    37998701          6987416
# 1  2011         Alabama     4745278     4024442      588293           117726
# 2  2011          Alaska      711962      571857      100280            35084
# 3  2011         Arizona     6402301     5107496     1028366           222877
# 4  2011        Arkansas     2906632     2421746      405831            69845
#
#     Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  106806.0  88850.0  211816.0   77226.0  ...   154243.0  404839.0  73211.0
# 1       NaN   1771.0    1677.0    1642.0  ...     8710.0    7973.0    300.0
# 2      93.0      NaN    2467.0     190.0  ...      388.0    2492.0    662.0
# 3     833.0   5001.0       NaN    1066.0  ...     1680.0   12688.0  10577.0
# 4     691.0    560.0     439.0       NaN  ...     6462.0   14767.0      0.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  18172.0  229227.0    190644.0        45956.0   105370.0  31991.0  1826277
# 1     66.0    4935.0      2621.0           65.0      417.0      9.0    14817
# 2     68.0    1488.0      4548.0           89.0       23.0    246.0     4741
# 3      0.0    2233.0     13940.0           70.0     6473.0   2510.0    43562
# 4      0.0    1245.0      1477.0           24.0      687.0    252.0     9210
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2011  California    37222678    31213310     5271168           468428
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 5   2087.0  7358.0  35650.0    2648.0  ...     8761.0  37087.0  8944.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5    745.0   15753.0     36481.0          832.0     5668.0   2047.0  269772
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2011  California    37222678    31213310     5271168           468428
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 0   2087.0  7358.0  35650.0    2648.0  ...     8761.0  37087.0  8944.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0    745.0   15753.0     36481.0          832.0     5668.0   2047.0  269772
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2011.csv"
df2.to_csv(file_path, index=False)
