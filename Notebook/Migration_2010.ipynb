# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2010.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States1                305,628,607  +/- 29,823
# 1                 Alabama                  4,729,509   +/- 3,716
# 2                  Alaska                    702,974   +/- 1,600
# 3                 Arizona                  6,332,786   +/- 4,439
# 4                Arkansas                  2,888,304   +/- 2,453
#
#   Same residence 1 year ago        MOE.1  \
# 0               258,552,348  +/- 236,128
# 1                 3,987,155   +/- 21,708
# 2                   565,031    +/- 7,596
# 3                 5,069,002   +/- 35,057
# 4                 2,387,806   +/- 18,627
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 38,582,885  +/- 213,239
# 1                                    620,465   +/- 21,448
# 2                                     95,878    +/- 7,984
# 3                                  1,001,991   +/- 32,027
# 4                                    412,997   +/- 17,485
#
#   Different state of residence 1 year ago       MOE.3 Alabama  ... Wyoming  \
# 0                               6,743,229  +/- 69,387  99,221  ...  28,186
# 1                                 108,723   +/- 8,781     NaN  ...      27
# 2                                  36,326   +/- 3,708     477  ...      81
# 3                                 222,725  +/- 11,873     416  ...     593
# 4                                  79,127   +/- 7,901   1,405  ...     443
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 3,185  1,750,145  +/- 36,993      59,885  +/- 6,923           17,167
# 1     +/- 52     13,166   +/- 2,247         228    +/- 265              181
# 2    +/- 131      5,739   +/- 1,602          19     +/- 30            1,374
# 3    +/- 393     39,068   +/- 6,046         599    +/- 771              223
# 4    +/- 513      8,374   +/- 2,099          87    +/- 146                0
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 3,479       1,673,093  +/- 36,130
# 1    +/- 160          12,757   +/- 2,241
# 2  +/- 1,188           4,346   +/- 1,205
# 3    +/- 286          38,246   +/- 5,951
# 4    +/- 273           8,287   +/- 2,123
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 0 null values
# Column MOE.56 has 0 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States1  305,628,607  258,552,348  38,582,885       6,743,229
# 1         Alabama    4,729,509    3,987,155     620,465         108,723
# 2          Alaska      702,974      565,031      95,878          36,326
# 3         Arizona    6,332,786    5,069,002   1,001,991         222,725
# 4        Arkansas    2,888,304    2,387,806     412,997          79,127
#
#   Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  99,221  94,692  176,768   64,264    573,988  ...   143,135  411,641
# 1     NaN   3,013      676    1,481      3,827  ...     7,409    6,500
# 2     477     NaN    1,354       47      3,906  ...       477    4,123
# 3     416   3,109      NaN      689     47,164  ...     3,061   14,705
# 4   1,405     934      777      NaN      4,457  ...     2,653   13,707
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  75,541  18,380  232,002    166,162        49,349   111,240  28,186
# 1   1,336       0    2,490      1,171            41     1,155      27
# 2   1,274     353      714      2,421             0       158      81
# 3   7,164     664    3,413     12,645           595     5,556     593
# 4     361       0      494        264             0       821     443
#
#        Total
# 0  1,750,145
# 1     13,166
# 2      5,739
# 3     39,068
# 4      8,374
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2010)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2010         United States1  305,628,607  258,552,348  38,582,885
# 1   2010                Alabama    4,729,509    3,987,155     620,465
# 2   2010                 Alaska      702,974      565,031      95,878
# 3   2010                Arizona    6,332,786    5,069,002   1,001,991
# 4   2010               Arkansas    2,888,304    2,387,806     412,997
# 5   2010             California   36,907,897   30,790,221   5,413,287
# 6   2010               Colorado    4,988,190    4,042,039     725,413
# 7   2010            Connecticut    3,541,146    3,100,742     342,904
# 8   2010               Delaware      889,812      764,640      90,001
# 9   2010  District of Columbia       596,747      474,676      63,766
# 10  2010                Florida   18,647,600   15,554,008   2,459,530
# 11  2010                Georgia    9,587,237    8,015,409   1,278,548
# 12  2010                 Hawaii    1,346,274    1,140,572     134,315
# 13  2010                  Idaho    1,550,967    1,279,856     209,272
# 14  2010               Illinois   12,680,126   11,009,852   1,404,525
# 15  2010                Indiana    6,414,862    5,431,015     833,086
# 16  2010                   Iowa    3,013,053    2,553,210     375,650
# 17  2010                 Kansas    2,820,894    2,341,401     372,161
# 18  2010               Kentucky    4,296,639    3,638,259     519,887
# 19  2010              Louisiana    4,483,529    3,826,390     547,291
# 20  2010                  Maine    1,313,902    1,136,780     146,735
# 21  2010               Maryland    5,716,785    4,917,637     588,879
# 22  2010          Massachusetts    6,489,250    5,583,650     706,624
# 23  2010               Michigan    9,762,127    8,310,098   1,291,901
# 24  2010              Minnesota    5,244,256    4,480,630     647,946
# 25  2010            Mississippi    2,931,228    2,510,729     340,266
# 26  2010               Missouri    5,920,858    4,968,921     786,726
# 27  2010                Montana      978,507      821,709     117,752
# 28  2010               Nebraska    1,802,697    1,497,138     247,005
# 29  2010                 Nevada    2,667,364    2,030,410     517,261
# 30  2010          New Hampshire    1,303,865    1,118,359     141,213
# 31  2010             New Jersey    8,709,933    7,841,470     684,482
# 32  2010             New Mexico    2,039,549    1,735,950     220,663
# 33  2010               New York   19,171,916   16,976,205   1,779,540
# 34  2010         North Carolina    9,443,000    7,982,017   1,141,001
# 35  2010           North Dakota      665,654      556,222      75,720
# 36  2010                   Ohio   11,405,101    9,745,227   1,453,401
# 37  2010               Oklahoma    3,716,264    3,065,497     528,824
# 38  2010                 Oregon    3,794,008    3,110,896     545,841
# 39  2010           Pennsylvania   12,577,555   11,053,022   1,239,199
# 40  2010           Rhode Island    1,042,240      900,283      99,603
# 41  2010         South Carolina    4,577,399    3,870,879     537,961
# 42  2010           South Dakota      805,616      680,993      96,805
# 43  2010              Tennessee    6,282,706    5,299,496     801,355
# 44  2010                  Texas   24,899,075   20,500,156   3,740,344
# 45  2010                   Utah    2,724,064    2,240,636     388,410
# 46  2010                Vermont      619,363      534,975      59,032
# 47  2010               Virginia    7,930,773    6,752,310     870,491
# 48  2010             Washington    6,661,321    5,464,985     946,923
# 49  2010          West Virginia    1,833,535    1,625,125     166,168
#
#    Different state Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        6,743,229  99,221  94,692  176,768   64,264  ...   143,135  411,641
# 1          108,723     NaN   3,013      676    1,481  ...     7,409    6,500
# 2           36,326     477     NaN    1,354       47  ...       477    4,123
# 3          222,725     416   3,109      NaN      689  ...     3,061   14,705
# 4           79,127   1,405     934      777      NaN  ...     2,653   13,707
# 5          444,749   3,364   9,579   33,854    4,172  ...     4,349   36,582
# 6          186,366     954   2,225   12,287    1,034  ...     1,628   22,253
# 7           77,333     896       0      664      334  ...       430    1,887
# 8           30,759     128      68       60        0  ...       146      178
# 9           51,244     360     591      662      155  ...       591    1,180
# 10         482,889  15,830   5,887    3,907    3,611  ...    12,882   24,039
# 11         249,459  13,840   3,645    2,554      599  ...    14,445   11,424
# 12          53,581     749     743    1,398        0  ...       142    6,694
# 13          55,638     376   3,264    3,086       45  ...     1,153    1,746
# 14         203,959   1,397   1,764    5,921    1,194  ...     3,999   12,245
# 15         127,353   1,502     177    2,210    1,548  ...     3,093    6,335
# 16          72,557     330     519    1,483      247  ...     1,617    4,131
# 17          95,059      44   1,050    2,238    1,596  ...     1,152    9,217
# 18         118,443   2,161   3,017    2,598      558  ...    11,153    5,758
# 19          97,889   5,740   1,504    1,960    2,382  ...     1,853   26,134
# 20          27,758     402     424      254       67  ...       249      458
# 21         164,484   1,641   2,672    1,124      273  ...     2,669    5,883
# 22         140,162     583   1,891    1,572      206  ...       918    7,073
# 23         116,149   2,403   1,040    3,197      636  ...     4,453    7,184
# 24          89,872     266   1,169    4,165      279  ...     1,155    2,619
# 25          72,321   8,306   1,192      187    4,941  ...     8,158    5,755
# 26         145,226     819   1,051    2,988    4,381  ...     3,311   12,884
# 27          35,630     212     650    1,909      672  ...       111    2,101
# 28          51,290     232      35    2,322      674  ...        77    4,445
# 29         102,677     150     511    7,818      530  ...       706    5,224
# 30          39,367     152       0      544        0  ...       372    1,570
# 31         127,369     616     383    1,625      258  ...       852    3,434
# 32          73,605     751     969    6,117       77  ...     1,269   18,511
# 33         269,427   1,310   5,070    2,649      362  ...     1,730    9,692
# 34         263,256   3,044   1,618    2,847      550  ...     8,685   14,329
# 35          30,100     109   1,066      662      168  ...       273    2,513
# 36         172,633   1,289   1,556    4,715      434  ...     4,987    7,465
# 37         106,511   1,612   1,397    2,759    5,873  ...     1,872   28,238
# 38         116,700     400   2,027    5,264      246  ...       787    3,826
# 39         235,580     369   2,185    3,668      807  ...     1,611    7,778
# 40          32,059     136       0      324        0  ...        71      678
# 41         152,441   1,741   1,670    1,457      365  ...     3,816    4,965
# 42          25,777     325      25      745       61  ...         0    1,334
# 43         159,778   8,897     343    2,291    4,736  ...       NaN    8,701
# 44         486,558   8,636  11,613   16,521   15,251  ...    13,044      NaN
# 45          77,780      93   1,798    8,147      316  ...       459    5,305
# 46          22,529       0     184       65        0  ...       125      565
# 47         259,507   2,671   3,296    3,807    1,233  ...     5,842   12,938
# 48         191,784   1,322   5,644    5,971      658  ...       789   11,338
# 49          39,609      41   1,326        0        0  ...     1,160      968
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   75,541  18,380  232,002    166,162        49,349   111,240  28,186
# 1    1,336       0    2,490      1,171            41     1,155      27
# 2    1,274     353      714      2,421             0       158      81
# 3    7,164     664    3,413     12,645           595     5,556     593
# 4      361       0      494        264             0       821     443
# 5   10,653     525   14,232     30,544         1,446     6,031   1,336
# 6    4,748     350    2,739      7,583           623     2,499   4,418
# 7        0     458    1,735      2,084           442     1,092      47
# 8        0       0    1,051        377             0         0       0
# 9        0     199    7,915        284           860       391       0
# 10   2,833   1,442   20,080      3,573         5,634     8,081     191
# 11     380     361    8,393      4,495           358     3,416     102
# 12     467       0    2,644      2,705           483     1,168      18
# 13   8,014       0      611     10,876           133       233   1,410
# 14     658     260    3,831      1,642           812    15,364     586
# 15     444      45    3,673        571           669     1,762     413
# 16     146      45      303        538             0     2,705     111
# 17     238      75    1,648      1,175             0     1,233     573
# 18     905     525    3,671        716         2,297     1,993     292
# 19     473       0    1,278      1,509           210       237      31
# 20     390     420      654        381             0         0     500
# 21     655     350   24,765      1,542         4,363       324     230
# 22     207   1,526    4,542      1,627             0       546       0
# 23     545      45    2,073      1,427           446     6,291     568
# 24   1,013       0    2,371      1,328           200    17,929     343
# 25     232       0      572        508            94       879     490
# 26   1,319     498    3,206      1,107           177     1,331     359
# 27     964       0      497      3,250             0       357   1,689
# 28     537       0      772      1,230            73     1,046   1,478
# 29   4,500     197    1,832      3,290            56       419     144
# 30     279   2,566      745        261             0       268       0
# 31     178      57    2,670        964           358       586       0
# 32   1,601     309      290      3,004             0       407     752
# 33     910   2,900    8,881      2,503           444     2,354     151
# 34     790     350   25,662      2,874         3,025     2,012     870
# 35     462       0       25        696             0       749     219
# 36     485     182    6,769      2,567         7,814     1,771     144
# 37     428      93    2,286      2,035           221       551   1,713
# 38   2,879     456    1,124     22,793           358     1,981     523
# 39   1,048     215   10,558      2,495         4,258     1,300   1,069
# 40       0      72    1,399        160           150         0       0
# 41     455     478    9,786      3,070         1,190     1,057     382
# 42       0       0      224      1,564             0       736     648
# 43   2,062       0    8,650      1,412         2,201     2,831       0
# 44   4,123      52   13,713      8,847         2,221     5,927   1,874
# 45     NaN     297    3,005      3,792             0       338   2,126
# 46       0     NaN      400        128             0       377      52
# 47   1,551     676      NaN      4,373         6,779     2,648     423
# 48   4,020     981    7,266        NaN            62     2,180     638
# 49     112     208    4,999        192           NaN       150       0
#
#         Total
# 0   1,750,145
# 1      13,166
# 2       5,739
# 3      39,068
# 4       8,374
# 5     259,640
# 6      34,372
# 7      20,167
# 8       4,412
# 9       7,061
# 10    151,173
# 11     43,821
# 12     17,806
# 13      6,201
# 14     61,790
# 15     23,408
# 16     11,636
# 17     12,273
# 18     20,050
# 19     11,959
# 20      2,629
# 21     45,785
# 22     58,814
# 23     43,979
# 24     25,808
# 25      7,912
# 26     19,985
# 27      3,416
# 28      7,264
# 29     17,016
# 30      4,926
# 31     56,612
# 32      9,331
# 33    146,744
# 34     56,726
# 35      3,612
# 36     33,840
# 37     15,432
# 38     20,571
# 39     49,754
# 40     10,295
# 41     16,118
# 42      2,041
# 43     22,077
# 44    172,017
# 45     17,238
# 46      2,827
# 47     48,465
# 48     57,629
# 49      2,633
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2010  United States1   305628607   258552348    38582885          6743229
# 1  2010         Alabama     4729509     3987155      620465           108723
# 2  2010          Alaska      702974      565031       95878            36326
# 3  2010         Arizona     6332786     5069002     1001991           222725
# 4  2010        Arkansas     2888304     2387806      412997            79127
#
#    Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  99221.0  94692.0  176768.0   64264.0  ...   143135.0  411641.0  75541.0
# 1      NaN   3013.0     676.0    1481.0  ...     7409.0    6500.0   1336.0
# 2    477.0      NaN    1354.0      47.0  ...      477.0    4123.0   1274.0
# 3    416.0   3109.0       NaN     689.0  ...     3061.0   14705.0   7164.0
# 4   1405.0    934.0     777.0       NaN  ...     2653.0   13707.0    361.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  18380.0  232002.0    166162.0        49349.0   111240.0  28186.0  1750145
# 1      0.0    2490.0      1171.0           41.0     1155.0     27.0    13166
# 2    353.0     714.0      2421.0            0.0      158.0     81.0     5739
# 3    664.0    3413.0     12645.0          595.0     5556.0    593.0    39068
# 4      0.0     494.0       264.0            0.0      821.0    443.0     8374
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2010.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2010  California    36907897    30790221     5413287           444749
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 5   3364.0  9579.0  33854.0    4172.0  ...     4349.0  36582.0  10653.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5    525.0   14232.0     30544.0         1446.0     6031.0   1336.0  259640
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2010  California    36907897    30790221     5413287           444749
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 0   3364.0  9579.0  33854.0    4172.0  ...     4349.0  36582.0  10653.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0    525.0   14232.0     30544.0         1446.0     6031.0   1336.0  259640
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2010.csv"
df2.to_csv(file_path, index=False)
