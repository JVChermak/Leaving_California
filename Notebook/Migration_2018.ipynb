# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2018.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States2                323,531,965  +/- 28,863
# 1                 Alabama                  4,832,358   +/- 3,328
# 2                  Alaska                    727,164   +/- 1,214
# 3                 Arizona                  7,090,137   +/- 4,507
# 4                Arkansas                  2,975,961   +/- 3,093
#
#   Same residence 1 year ago        MOE.1  \
# 0               278,079,469  +/- 191,887
# 1                 4,173,026   +/- 19,530
# 2                   608,707    +/- 7,474
# 3                 5,887,700   +/- 28,309
# 4                 2,539,294   +/- 19,535
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 35,921,585  +/- 160,760
# 1                                    534,914   +/- 18,557
# 2                                     81,229    +/- 5,883
# 3                                    888,452   +/- 25,934
# ...

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# ...

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
# ...

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States2  323,531,965  278,079,469  35,921,585       7,571,282
# 1         Alabama    4,832,358    4,173,026     534,914         109,301
# 2          Alaska      727,164      608,707      81,229          32,099
# 3         Arizona    7,090,137    5,887,700     888,452         273,714
# 4        Arkansas    2,975,961    2,539,294     354,774          73,179
#
#   Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  98,194  39,246  179,586   69,724    691,145  ...   173,250  462,140
# 1     NaN     419    1,915    1,051      2,659  ...    12,228    5,719
# 2     518     NaN      910      722      3,455  ...       171    2,322
# 3   2,801   2,743      NaN    1,487     68,516  ...     1,291   20,245
# 4     438     413      602      NaN      3,728  ...     5,492   15,531
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# ...

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2018)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2018         United States2  323,531,965  278,079,469  35,921,585
# 1   2018                Alabama    4,832,358    4,173,026     534,914
# 2   2018                 Alaska      727,164      608,707      81,229
# 3   2018                Arizona    7,090,137    5,887,700     888,452
# 4   2018               Arkansas    2,975,961    2,539,294     354,774
# 5   2018             California   39,114,889   34,232,867   4,092,388
# 6   2018               Colorado    5,633,029    4,626,834     728,730
# 7   2018            Connecticut    3,538,203    3,102,312     320,248
# 8   2018               Delaware      958,770      853,523      67,984
# 9   2018  District of Columbia       693,798      568,201      68,603
# 10  2018                Florida   21,092,877   17,863,603   2,420,485
# 11  2018                Georgia   10,410,462    8,909,803   1,174,523
# ...

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# ...

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2018  United States2   323531965   278079469    35921585          7571282
# 1  2018         Alabama     4832358     4173026      534914           109301
# 2  2018          Alaska      727164      608707       81229            32099
# 3  2018         Arizona     7090137     5887700      888452           273714
# 4  2018        Arkansas     2975961     2539294      354774            73179
#
#    Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  98194.0  39246.0  179586.0   69724.0  ...   173250.0  462140.0  91741.0
# 1      NaN    419.0    1915.0    1051.0  ...    12228.0    5719.0     79.0
# 2    518.0      NaN     910.0     722.0  ...      171.0    2322.0    410.0
# 3   2801.0   2743.0       NaN    1487.0  ...     1291.0   20245.0   5828.0
# 4    438.0    413.0     602.0       NaN  ...     5492.0   15531.0    712.0
#
# ...

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# ...

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2018  California    39114889    34232867     4092388           501023
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 5   4591.0  2155.0  33670.0    2573.0  ...     8060.0  37810.0  9440.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5   1641.0   17725.0     38007.0         1246.0     5364.0   1526.0  288611
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2018  California    39114889    34232867     4092388           501023
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas    Utah  \
# 0   4591.0  2155.0  33670.0    2573.0  ...     8060.0  37810.0  9440.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0   1641.0   17725.0     38007.0         1246.0     5364.0   1526.0  288611
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2018.csv"
df2.to_csv(file_path, index=False)
