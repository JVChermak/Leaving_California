# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
df = pd.read_csv("../Resources/data/migration_2013.csv")
df.head()
# Out:
#   Current residence in -- Population 1 year and over         MOE  \
# 0          United States1                312,432,820  +/- 28,736
# 1                 Alabama                  4,781,296   +/- 3,371
# 2                  Alaska                    725,193   +/- 1,551
# 3                 Arizona                  6,543,362   +/- 4,567
# 4                Arkansas                  2,923,642   +/- 3,216
#
#   Same residence 1 year ago        MOE.1  \
# 0               265,461,391  +/- 215,531
# 1                 4,067,683   +/- 20,967
# 2                   583,799    +/- 9,191
# 3                 5,321,158   +/- 29,468
# 4                 2,475,807   +/- 16,481
#
#   Different residence, same state 1 year ago        MOE.2  \
# 0                                 37,860,849  +/- 181,528
# 1                                    594,583   +/- 19,882
# 2                                     99,953    +/- 8,006
# 3                                    941,347   +/- 27,201
# 4                                    367,837   +/- 13,479
#
#   Different state of residence 1 year ago       MOE.3 Alabama  ... Wyoming  \
# 0                               7,207,333  +/- 70,975  97,219  ...  28,150
# 1                                 104,102   +/- 7,789     NaN  ...     282
# 2                                  34,360   +/- 4,808     572  ...       0
# 3                                 236,146  +/- 10,894   2,140  ...   1,838
# 4                                  70,621   +/- 8,082       0  ...       0
#
#       MOE.54      Total      MOE.55 Puerto Rico     MOE.56 U.S. Island Area  \
# 0  +/- 4,294  1,903,247  +/- 36,322      73,846  +/- 9,838           18,416
# 1    +/- 272     14,928   +/- 3,443         312    +/- 330              156
# 2    +/- 193      7,081   +/- 1,794         184    +/- 202               25
# 3    +/- 909     44,711   +/- 4,328         376    +/- 194              386
# 4    +/- 193      9,377   +/- 2,360           8     +/- 30              187
#
#       MOE.57 Foreign Country      MOE.58
# 0  +/- 3,666       1,810,985  +/- 33,055
# 1    +/- 163          14,460   +/- 3,423
# 2     +/- 39           6,872   +/- 1,748
# 3    +/- 348          43,949   +/- 4,314
# 4    +/- 189           9,182   +/- 2,361
#
# [5 rows x 119 columns]

# %%
# List row and column counts
df.shape
# Out:
# (53, 119)

# %%
# List dataframe data types
df.dtypes
# Out:
# Current residence in --       object
# Population 1 year and over    object
# MOE                           object
# Same residence 1 year ago     object
# MOE.1                         object
#                                ...
# MOE.56                        object
# U.S. Island Area              object
# MOE.57                        object
# Foreign Country               object
# MOE.58                        object
# Length: 119, dtype: object

# %%
# Find null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column Current residence in -- has 0 null values
# Column Population 1 year and over has 0 null values
# Column MOE has 0 null values
# Column Same residence 1 year ago has 0 null values
# Column MOE.1 has 0 null values
# Column Different residence, same state 1 year ago has 0 null values
# Column MOE.2 has 0 null values
# Column Different state of residence 1 year ago has 0 null values
# Column MOE.3 has 0 null values
# Column Alabama has 1 null values
# Column MOE.4 has 1 null values
# Column Alaska has 1 null values
# Column MOE.5 has 1 null values
# Column Arizona has 1 null values
# Column MOE.6 has 1 null values
# Column Arkansas has 1 null values
# Column MOE.7 has 1 null values
# Column California has 1 null values
# Column MOE.8 has 1 null values
# Column Colorado has 1 null values
# Column MOE.9 has 1 null values
# Column Connecticut has 1 null values
# Column MOE.10 has 1 null values
# Column Delaware has 1 null values
# Column MOE.11 has 1 null values
# Column District of Columbia  has 1 null values
# Column MOE.12 has 1 null values
# Column Florida has 1 null values
# Column MOE.13 has 1 null values
# Column Georgia has 1 null values
# Column MOE.14 has 1 null values
# Column Hawaii has 1 null values
# Column MOE.15 has 1 null values
# Column Idaho has 1 null values
# Column MOE.16 has 1 null values
# Column Illinois has 1 null values
# Column MOE.17 has 1 null values
# Column Indiana has 1 null values
# Column MOE.18 has 1 null values
# Column Iowa has 1 null values
# Column MOE.19 has 1 null values
# Column Kansas has 1 null values
# Column MOE.20 has 1 null values
# Column Kentucky has 1 null values
# Column MOE.21 has 1 null values
# Column Louisiana has 1 null values
# Column MOE.22 has 1 null values
# Column Maine has 1 null values
# Column MOE.23 has 1 null values
# Column Maryland has 1 null values
# Column MOE.24 has 1 null values
# Column Massachusetts has 1 null values
# Column MOE.25 has 1 null values
# Column Michigan has 1 null values
# Column MOE.26 has 1 null values
# Column Minnesota has 1 null values
# Column MOE.27 has 1 null values
# Column Mississippi has 1 null values
# Column MOE.28 has 1 null values
# Column Missouri has 1 null values
# Column MOE.29 has 1 null values
# Column Montana has 1 null values
# Column MOE.30 has 1 null values
# Column Nebraska has 1 null values
# Column MOE.31 has 1 null values
# Column Nevada has 1 null values
# Column MOE.32 has 1 null values
# Column New Hampshire has 1 null values
# Column MOE.33 has 1 null values
# Column New Jersey has 1 null values
# Column MOE.34 has 1 null values
# Column New Mexico has 1 null values
# Column MOE.35 has 1 null values
# Column New York has 1 null values
# Column MOE.36 has 1 null values
# Column North Carolina has 1 null values
# Column MOE.37 has 1 null values
# Column North Dakota has 1 null values
# Column MOE.38 has 1 null values
# Column Ohio has 1 null values
# Column MOE.39 has 1 null values
# Column Oklahoma has 1 null values
# Column MOE.40 has 1 null values
# Column Oregon has 1 null values
# Column MOE.41 has 1 null values
# Column Pennsylvania has 1 null values
# Column MOE.42 has 1 null values
# Column Rhode Island has 1 null values
# Column MOE.43 has 1 null values
# Column South Carolina has 1 null values
# Column MOE.44 has 1 null values
# Column South Dakota has 1 null values
# Column MOE.45 has 1 null values
# Column Tennessee has 1 null values
# Column MOE.46 has 1 null values
# Column Texas has 1 null values
# Column MOE.47 has 1 null values
# Column Utah has 1 null values
# Column MOE.48 has 1 null values
# Column Vermont has 1 null values
# Column MOE.49 has 1 null values
# Column Virginia has 1 null values
# Column MOE.50 has 1 null values
# Column Washington has 1 null values
# Column MOE.51 has 1 null values
# Column West Virginia has 1 null values
# Column MOE.52 has 1 null values
# Column Wisconsin has 1 null values
# Column MOE.53 has 1 null values
# Column Wyoming has 1 null values
# Column MOE.54 has 1 null values
# Column Total has 0 null values
# Column MOE.55 has 0 null values
# Column Puerto Rico has 0 null values
# Column MOE.56 has 0 null values
# Column U.S. Island Area has 0 null values
# Column MOE.57 has 0 null values
# Column Foreign Country has 0 null values
# Column MOE.58 has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# List column names
list(df)
# Out:
# ['Current residence in --',
#  'Population 1 year and over',
#  'MOE',
#  'Same residence 1 year ago',
#  'MOE.1',
#  'Different residence, same state 1 year ago',
#  'MOE.2',
#  'Different state of residence 1 year ago',
#  'MOE.3',
#  'Alabama',
#  'MOE.4',
#  'Alaska',
#  'MOE.5',
#  'Arizona',
#  'MOE.6',
#  'Arkansas',
#  'MOE.7',
#  'California',
#  'MOE.8',
#  'Colorado',
#  'MOE.9',
#  'Connecticut',
#  'MOE.10',
#  'Delaware',
#  'MOE.11',
#  'District of Columbia ',
#  'MOE.12',
#  'Florida',
#  'MOE.13',
#  'Georgia',
#  'MOE.14',
#  'Hawaii',
#  'MOE.15',
#  'Idaho',
#  'MOE.16',
#  'Illinois',
#  'MOE.17',
#  'Indiana',
#  'MOE.18',
#  'Iowa',
#  'MOE.19',
#  'Kansas',
#  'MOE.20',
#  'Kentucky',
#  'MOE.21',
#  'Louisiana',
#  'MOE.22',
#  'Maine',
#  'MOE.23',
#  'Maryland',
#  'MOE.24',
#  'Massachusetts',
#  'MOE.25',
#  'Michigan',
#  'MOE.26',
#  'Minnesota',
#  'MOE.27',
#  'Mississippi',
#  'MOE.28',
#  'Missouri',
#  'MOE.29',
#  'Montana',
#  'MOE.30',
#  'Nebraska',
#  'MOE.31',
#  'Nevada',
#  'MOE.32',
#  'New Hampshire',
#  'MOE.33',
#  'New Jersey',
#  'MOE.34',
#  'New Mexico',
#  'MOE.35',
#  'New York',
#  'MOE.36',
#  'North Carolina',
#  'MOE.37',
#  'North Dakota',
#  'MOE.38',
#  'Ohio',
#  'MOE.39',
#  'Oklahoma',
#  'MOE.40',
#  'Oregon',
#  'MOE.41',
#  'Pennsylvania',
#  'MOE.42',
#  'Rhode Island',
#  'MOE.43',
#  'South Carolina',
#  'MOE.44',
#  'South Dakota',
#  'MOE.45',
#  'Tennessee',
#  'MOE.46',
#  'Texas',
#  'MOE.47',
#  'Utah',
#  'MOE.48',
#  'Vermont',
#  'MOE.49',
#  'Virginia',
#  'MOE.50',
#  'Washington',
#  'MOE.51',
#  'West Virginia',
#  'MOE.52',
#  'Wisconsin',
#  'MOE.53',
#  'Wyoming',
#  'MOE.54',
#  'Total',
#  'MOE.55',
#  'Puerto Rico',
#  'MOE.56',
#  'U.S. Island Area',
#  'MOE.57',
#  'Foreign Country',
#  'MOE.58']

# %%
# Only view needed column information
df2 = df.filter(items=['Current residence in --',
                 'Population 1 year and over',
                 'Same residence 1 year ago',
                 'Different residence, same state 1 year ago',
                 'Different state of residence 1 year ago',
                 'Alabama',
                 'Alaska',
                 'Arizona',
                 'Arkansas',
                 'California',
                 'Colorado',
                 'Connecticut',
                 'Delaware',
                 'District of Columbia ',
                 'Florida',
                 'Georgia',
                 'Hawaii',
                 'Idaho',
                 'Illinois',
                 'Indiana',
                 'Iowa',
                 'Kansas',
                 'Kentucky',
                 'Louisiana',
                 'Maine',
                 'Maryland',
                 'Massachusetts',
                 'Michigan',
                 'Minnesota',
                 'Mississippi',
                 'Missouri',
                 'Montana',
                 'Nebraska',
                 'Nevada',
                 'New Hampshire',
                 'New Jersey',
                 'New Mexico',
                 'New York',
                 'North Carolina',
                 'North Dakota',
                 'Ohio',
                 'Oklahoma',
                 'Oregon',
                 'Pennsylvania',
                 'Rhode Island',
                 'South Carolina',
                 'South Dakota',
                 'Tennessee',
                 'Texas',
                 'Utah',
                 'Vermont',
                 'Virginia',
                 'Washington',
                 'West Virginia',
                 'Wisconsin',
                 'Wyoming',
                 'Total'])

# %%
# Change column names
df2.rename(columns={'Current residence in --': 'Name',
                       'Population 1 year and over': 'Population',
                       'Same residence 1 year ago': 'Same house',
                       'Different residence, same state 1 year ago': 'Same state',
                       'Different state of residence 1 year ago': 'Different state'}, inplace=True)
df2.head()
# Out:
#              Name   Population   Same house  Same state Different state  \
# 0  United States1  312,432,820  265,461,391  37,860,849       7,207,333
# 1         Alabama    4,781,296    4,067,683     594,583         104,102
# 2          Alaska      725,193      583,799      99,953          34,360
# 3         Arizona    6,543,362    5,321,158     941,347         236,146
# 4        Arkansas    2,923,642    2,475,807     367,837          70,621
#
#   Alabama  Alaska  Arizona Arkansas California  ... Tennessee    Texas  \
# 0  97,219  99,931  183,178   76,963    581,679  ...   159,497  409,977
# 1     NaN   1,026    1,077    1,108      4,918  ...     8,806    4,413
# 2     572     NaN      733      403      2,874  ...       570    2,477
# 3   2,140   4,418      NaN      310     47,959  ...     3,292   17,742
# 4       0   1,193      661      NaN      4,925  ...     4,285   12,937
#
#      Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0  91,943  21,773  236,420    191,053        48,627   110,198  28,150
# 1   1,881      19    3,303        589           109       296     282
# 2   1,363       6      727      2,984           257       216       0
# 3   9,093     306    3,771     14,756           188     5,694   1,838
# 4     237       0      514        520           150       331       0
#
#        Total
# 0  1,903,247
# 1     14,928
# 2      7,081
# 3     44,711
# 4      9,377
#
# [5 rows x 57 columns]

# %%
# Adding 'Year' column
df2.insert(0, 'Year', 2013)
df2.head(50)
# Out:
#     Year                   Name   Population   Same house  Same state  \
# 0   2013         United States1  312,432,820  265,461,391  37,860,849
# 1   2013                Alabama    4,781,296    4,067,683     594,583
# 2   2013                 Alaska      725,193      583,799      99,953
# 3   2013                Arizona    6,543,362    5,321,158     941,347
# 4   2013               Arkansas    2,923,642    2,475,807     367,837
# 5   2013             California   37,873,189   32,197,933   4,898,331
# 6   2013               Colorado    5,206,012    4,186,643     778,520
# 7   2013            Connecticut    3,562,959    3,127,421     325,895
# 8   2013               Delaware      914,025      791,278      81,363
# 9   2013  District of Columbia       636,535      509,958      68,917
# 10  2013                Florida   19,345,059   16,199,361   2,442,119
# 11  2013                Georgia    9,870,319    8,256,209   1,279,601
# 12  2013                 Hawaii    1,387,361    1,177,733     135,860
# 13  2013                  Idaho    1,592,596    1,317,235     205,418
# 14  2013               Illinois   12,740,816   11,036,387   1,411,859
# 15  2013                Indiana    6,492,306    5,499,346     835,689
# 16  2013                   Iowa    3,053,635    2,585,189     380,270
# 17  2013                 Kansas    2,854,869    2,386,028     363,906
# 18  2013               Kentucky    4,345,186    3,665,604     558,412
# 19  2013              Louisiana    4,568,320    3,941,211     519,010
# 20  2013                  Maine    1,315,753    1,128,262     146,334
# 21  2013               Maryland    5,857,213    5,078,020     572,131
# 22  2013          Massachusetts    6,619,999    5,724,592     700,613
# 23  2013               Michigan    9,784,094    8,296,283   1,294,706
# 24  2013              Minnesota    5,353,441    4,585,137     636,274
# 25  2013            Mississippi    2,957,797    2,531,410     350,982
# 26  2013               Missouri    5,973,448    5,015,609     779,132
# 27  2013                Montana    1,003,013      827,494     130,187
# 28  2013               Nebraska    1,842,900    1,546,788     241,707
# 29  2013                 Nevada    2,757,365    2,166,730     447,480
# 30  2013          New Hampshire    1,310,978    1,128,583     131,200
# 31  2013             New Jersey    8,803,679    7,941,559     667,248
# 32  2013             New Mexico    2,059,689    1,764,969     224,508
# 33  2013               New York   19,431,954   17,297,785   1,715,158
# 34  2013         North Carolina    9,737,365    8,233,641   1,176,351
# 35  2013           North Dakota      714,804      593,677      78,944
# 36  2013                   Ohio   11,439,593    9,748,676   1,458,505
# 37  2013               Oklahoma    3,801,521    3,131,192     545,546
# 38  2013                 Oregon    3,888,216    3,154,813     571,472
# 39  2013           Pennsylvania   12,639,493   11,113,742   1,240,573
# 40  2013           Rhode Island    1,040,986      905,093      94,129
# 41  2013         South Carolina    4,720,602    4,000,306     537,062
# 42  2013           South Dakota      832,703      691,659     108,713
# 43  2013              Tennessee    6,419,226    5,429,144     779,329
# 44  2013                  Texas   26,087,349   21,658,382   3,695,565
# 45  2013                   Utah    2,854,667    2,361,079     377,528
# 46  2013                Vermont      621,256      542,002      53,684
# 47  2013               Virginia    8,163,664    6,874,626     962,359
# 48  2013             Washington    6,888,552    5,700,703     927,367
# 49  2013          West Virginia    1,837,863    1,621,269     161,679
#
#    Different state Alabama  Alaska  Arizona Arkansas  ... Tennessee    Texas  \
# 0        7,207,333  97,219  99,931  183,178   76,963  ...   159,497  409,977
# 1          104,102     NaN   1,026    1,077    1,108  ...     8,806    4,413
# 2           34,360     572     NaN      733      403  ...       570    2,477
# 3          236,146   2,140   4,418      NaN      310  ...     3,292   17,742
# 4           70,621       0   1,193      661      NaN  ...     4,285   12,937
# 5          485,477   2,958   8,457   36,567    3,687  ...     7,020   32,290
# 6          206,543   2,926   1,606    8,798    1,235  ...     2,295   23,490
# 7           88,351     337   1,688    1,791        0  ...     1,139    1,997
# 8           36,790       0     272        0        0  ...       163      240
# 9           46,571     316     579       79        0  ...       560    1,625
# 10         529,406  10,281  10,876    7,553    1,577  ...    13,232   24,226
# 11         278,972  18,739   3,143    3,464    1,685  ...    18,867   14,949
# 12          58,083     593   1,615    1,153       24  ...       385    7,385
# 13          61,592      72   2,887    2,915      701  ...       625    1,937
# 14         223,605   2,044   2,624    5,598    1,586  ...     6,023   11,775
# 15         133,508   1,235     649    3,093      375  ...     2,626    7,136
# 16          75,650     180   1,539      968      684  ...       789    3,420
# 17          89,735   1,074     958    1,582    2,632  ...       970    9,309
# 18         103,207   1,418   1,388    1,057      340  ...     8,355    5,983
# 19          91,889   2,683   1,369      231    1,516  ...     3,566   21,747
# 20          36,780      13     912      510        0  ...       158      694
# 21         161,525   1,918   1,589    1,515      203  ...     1,215    5,385
# 22         135,150     409   1,634    2,507      287  ...       800    2,884
# 23         144,091   2,517   4,783    3,372    2,628  ...     4,529    7,139
# 24         104,825     493   1,564    3,389      952  ...       631    6,343
# 25          68,588   7,077     401    1,129    1,700  ...    11,928    8,157
# 26         159,936   1,004     438    3,763    8,024  ...     2,465    9,905
# 27          40,035      21   2,017      914       71  ...        31    2,082
# 28          45,854     294     440    1,585      348  ...        59    3,003
# 29         126,583     491   1,466    3,921    1,636  ...       976    5,212
# 30          44,867     123     598      360    1,084  ...       321      902
# 31         136,907     853     990      979      139  ...     1,187    4,302
# 32          56,808      63     420    5,551      104  ...       622   13,726
# 33         272,066   1,648   6,790    3,642      699  ...     1,458   13,125
# 34         275,922   3,268   4,199    4,437    1,350  ...     7,249    9,617
# 35          38,908       0     159    1,312        0  ...       128    2,989
# 36         185,749   1,318     663    2,793      738  ...     5,100    5,773
# 37         109,255   1,024   1,550    3,203    8,702  ...     1,385   27,391
# 38         143,841     704   3,439    7,611      608  ...       741    8,185
# 39         224,280     720     667    2,189    1,971  ...     3,335    9,631
# 40          34,108     279     102       22        0  ...         6      569
# 41         166,047   1,715   1,128    2,054    1,970  ...     2,952    5,834
# 42          30,042      84     141    1,691        0  ...       767    1,390
# 43         186,525   8,500   2,079    3,787    4,753  ...       NaN   12,023
# 44         548,034   8,404   7,252   19,224   16,844  ...    14,363      NaN
# 45          97,869     574   1,341    5,259    1,149  ...     1,263    5,635
# 46          23,180      27       0      138       11  ...       114      509
# 47         266,348   4,894   2,226    3,518      790  ...     5,372   12,790
# 48         208,215     686   3,422   10,591    2,088  ...     2,054   13,742
# 49          51,957     196     707       62       67  ...     1,235    1,199
#
#       Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming  \
# 0   91,943  21,773  236,420    191,053        48,627   110,198  28,150
# 1    1,881      19    3,303        589           109       296     282
# 2    1,363       6      727      2,984           257       216       0
# 3    9,093     306    3,771     14,756           188     5,694   1,838
# 4      237       0      514        520           150       331       0
# 5   12,631   1,029   12,810     37,246           967     4,704   1,030
# 6    6,240     689    6,980      6,173           246     2,623   4,307
# 7      433     621    2,665        672           183       435     132
# 8        0       0      776          0            53         0       0
# 9      126       0    7,814        159           391         5       3
# 10   2,129   1,434   18,132      6,975         4,250     7,321     341
# 11   1,568     200    9,464      2,090           645     3,066     562
# 12     521       0    1,373      3,225             0       231       0
# 13   6,771       0    1,117     10,059             0       334   1,508
# 14   1,349   1,032    5,314      4,300         1,074    15,844     202
# 15   1,390     261    2,520      2,348           160     2,490      13
# 16   1,212     367      487      1,097           147     5,219     423
# 17     376      68      729      1,185           330       709     181
# 18     629     254    3,330      1,144         1,772     1,237     231
# 19   1,261       0    2,662      2,162           726       517       0
# 20      63   1,358      548        513           155        17      70
# 21   1,836     416   24,308      2,223         4,653     1,379     313
# 22     402   2,881    5,964        940           222       718      92
# 23     708     268    2,106      1,057           319     5,297     154
# 24   1,166     198    1,512      2,476           596    17,649     213
# 25      28       0    1,116         98           126       285       0
# 26     217       0    1,326      2,443           756     2,343      59
# 27   1,797     318      501      5,390            50       875     987
# 28   1,083       0      605        498            36       352     496
# 29   6,727       0    1,881      4,469            66     1,703     887
# 30      27   2,417      501        513           550       337       0
# 31     370     871    4,877        801           461       115       0
# 32   2,818       0    1,701      1,073           198       509     273
# 33     822   2,412   11,810      2,792           725     1,412     309
# 34   1,084     863   30,058      1,929         3,684     1,449      35
# 35     487     117      558        642             0       464     857
# 36   1,794     393    5,206      3,099         9,890     2,390     151
# 37     568       0    2,369      1,076           589     1,125     561
# 38   3,518     115    3,264     29,782             0     1,064   1,022
# 39     972     621    9,392      2,460         3,524     1,586     515
# 40       0     857      603        106            52         0       0
# 41     164     184    7,352      2,371         1,347     1,229      86
# 42      80      84      298        881            42       498     981
# 43     506      37    6,612      2,328           835     2,809     126
# 44   5,684       0   14,313     11,124         1,578     6,646   4,640
# 45     NaN     329    2,279      4,316             0       618   3,700
# 46     436     NaN      416        386             0        52      68
# 47   2,195     349      NaN      5,051         6,047     1,524      59
# 48   5,536     167    3,592        NaN            89     4,190     400
# 49     177      27    6,045         49           NaN       110       0
#
#         Total
# 0   1,903,247
# 1      14,928
# 2       7,081
# 3      44,711
# 4       9,377
# 5     291,448
# 6      34,306
# 7      21,292
# 8       4,594
# 9      11,089
# 10    174,173
# 11     55,537
# 12     15,685
# 13      8,351
# 14     68,965
# 15     23,763
# 16     12,526
# 17     15,200
# 18     17,963
# 19     16,210
# 20      4,377
# 21     45,537
# 22     59,644
# 23     49,014
# 24     27,205
# 25      6,817
# 26     18,771
# 27      5,297
# 28      8,551
# 29     16,572
# 30      6,328
# 31     57,965
# 32     13,404
# 33    146,945
# 34     51,451
# 35      3,275
# 36     46,663
# 37     15,528
# 38     18,090
# 39     60,898
# 40      7,656
# 41     17,187
# 42      2,289
# 43     24,228
# 44    185,368
# 45     18,191
# 46      2,390
# 47     60,331
# 48     52,267
# 49      2,958
#
# [50 rows x 58 columns]

# %%
# Is the data in a format that can be passed into an unsupervised learning model?
df2.dtypes
# Out:
# Year                      int64
# Name                     object
# Population               object
# Same house               object
# Same state               object
# Different state          object
# Alabama                  object
# Alaska                   object
# Arizona                  object
# Arkansas                 object
# California               object
# Colorado                 object
# Connecticut              object
# Delaware                 object
# District of Columbia     object
# Florida                  object
# Georgia                  object
# Hawaii                   object
# Idaho                    object
# Illinois                 object
# Indiana                  object
# Iowa                     object
# Kansas                   object
# Kentucky                 object
# Louisiana                object
# Maine                    object
# Maryland                 object
# Massachusetts            object
# Michigan                 object
# Minnesota                object
# Mississippi              object
# Missouri                 object
# Montana                  object
# Nebraska                 object
# Nevada                   object
# New Hampshire            object
# New Jersey               object
# New Mexico               object
# New York                 object
# North Carolina           object
# North Dakota             object
# Ohio                     object
# Oklahoma                 object
# Oregon                   object
# Pennsylvania             object
# Rhode Island             object
# South Carolina           object
# South Dakota             object
# Tennessee                object
# Texas                    object
# Utah                     object
# Vermont                  object
# Virginia                 object
# Washington               object
# West Virginia            object
# Wisconsin                object
# Wyoming                  object
# Total                    object
# dtype: object

# %%
# Temporarily delete Name column to convert entire df to numeric
del df2['Name']

# %%
cols = ['Population',
        'Same house',
        'Same state',
        'Different state',
        'Alabama',
        'Alaska',
        'Arizona',
        'Arkansas',
        'California',
        'Colorado',
        'Connecticut',
        'Delaware',
        'District of Columbia ',
        'Florida',
        'Georgia',
        'Hawaii',
        'Idaho',
        'Illinois',
        'Indiana',
        'Iowa',
        'Kansas',
        'Kentucky',
        'Louisiana',
        'Maine',
        'Maryland',
        'Massachusetts',
        'Michigan',
        'Minnesota',
        'Mississippi',
        'Missouri',
        'Montana',
        'Nebraska',
        'Nevada',
        'New Hampshire',
        'New Jersey',
        'New Mexico',
        'New York',
        'North Carolina',
        'North Dakota',
        'Ohio',
        'Oklahoma',
        'Oregon',
        'Pennsylvania',
        'Rhode Island',
        'South Carolina',
        'South Dakota',
        'Tennessee',
        'Texas',
        'Utah',
        'Vermont',
        'Virginia',
        'Washington',
        'West Virginia',
        'Wisconsin',
        'Wyoming',
        'Total']

# %%
# Remove all the commas
df2[cols] = df2[cols].replace({',': ''}, regex=True)

# %%
# Convert entire df to numeric
df2 = df2.apply(pd.to_numeric)

# %%
# Return the Name column
df2.insert(1, 'Name', df['Current residence in --'])
df2.head()
# Out:
#    Year            Name  Population  Same house  Same state  Different state  \
# 0  2013  United States1   312432820   265461391    37860849          7207333
# 1  2013         Alabama     4781296     4067683      594583           104102
# 2  2013          Alaska      725193      583799       99953            34360
# 3  2013         Arizona     6543362     5321158      941347           236146
# 4  2013        Arkansas     2923642     2475807      367837            70621
#
#    Alabama   Alaska   Arizona  Arkansas  ...  Tennessee     Texas     Utah  \
# 0  97219.0  99931.0  183178.0   76963.0  ...   159497.0  409977.0  91943.0
# 1      NaN   1026.0    1077.0    1108.0  ...     8806.0    4413.0   1881.0
# 2    572.0      NaN     733.0     403.0  ...      570.0    2477.0   1363.0
# 3   2140.0   4418.0       NaN     310.0  ...     3292.0   17742.0   9093.0
# 4      0.0   1193.0     661.0       NaN  ...     4285.0   12937.0    237.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming    Total
# 0  21773.0  236420.0    191053.0        48627.0   110198.0  28150.0  1903247
# 1     19.0    3303.0       589.0          109.0      296.0    282.0    14928
# 2      6.0     727.0      2984.0          257.0      216.0      0.0     7081
# 3    306.0    3771.0     14756.0          188.0     5694.0   1838.0    44711
# 4      0.0     514.0       520.0          150.0      331.0      0.0     9377
#
# [5 rows x 58 columns]

# %%
# Make sure all dtypes are numeric
df2.dtypes
# Out:
# Year                       int64
# Name                      object
# Population                 int64
# Same house                 int64
# Same state                 int64
# Different state            int64
# Alabama                  float64
# Alaska                   float64
# Arizona                  float64
# Arkansas                 float64
# California               float64
# Colorado                 float64
# Connecticut              float64
# Delaware                 float64
# District of Columbia     float64
# Florida                  float64
# Georgia                  float64
# Hawaii                   float64
# Idaho                    float64
# Illinois                 float64
# Indiana                  float64
# Iowa                     float64
# Kansas                   float64
# Kentucky                 float64
# Louisiana                float64
# Maine                    float64
# Maryland                 float64
# Massachusetts            float64
# Michigan                 float64
# Minnesota                float64
# Mississippi              float64
# Missouri                 float64
# Montana                  float64
# Nebraska                 float64
# Nevada                   float64
# New Hampshire            float64
# New Jersey               float64
# New Mexico               float64
# New York                 float64
# North Carolina           float64
# North Dakota             float64
# Ohio                     float64
# Oklahoma                 float64
# Oregon                   float64
# Pennsylvania             float64
# Rhode Island             float64
# South Carolina           float64
# South Dakota             float64
# Tennessee                float64
# Texas                    float64
# Utah                     float64
# Vermont                  float64
# Virginia                 float64
# Washington               float64
# West Virginia            float64
# Wisconsin                float64
# Wyoming                  float64
# Total                      int64
# dtype: object

# %%
# Saving cleaned data
#file_path = "../Resources/clean_data/Migration/migration_2011.csv"
#df2.to_csv(file_path, index=False)

# %%
df2 = df2.loc[df2['Name'] == 'California']

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 5  2013  California    37873189    32197933     4898331           485477
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 5   2958.0  8457.0  36567.0    3687.0  ...     7020.0  32290.0  12631.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 5   1029.0   12810.0     37246.0          967.0     4704.0   1030.0  291448
#
# [1 rows x 58 columns]

# %%
# Reset the index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Year        Name  Population  Same house  Same state  Different state  \
# 0  2013  California    37873189    32197933     4898331           485477
#
#    Alabama  Alaska  Arizona  Arkansas  ...  Tennessee    Texas     Utah  \
# 0   2958.0  8457.0  36567.0    3687.0  ...     7020.0  32290.0  12631.0
#
#    Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming   Total
# 0   1029.0   12810.0     37246.0          967.0     4704.0   1030.0  291448
#
# [1 rows x 58 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Migration/ca_migration_2013.csv"
df2.to_csv(file_path, index=False)
