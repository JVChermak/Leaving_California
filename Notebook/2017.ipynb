# %%
# Import our dependencies
import pandas as pd
import numpy as np

# %%
# Read in our data
census = pd.read_csv("../Resources/clean_data/Cost/census_2017.csv")

# %%
# Read in our data
pop = pd.read_csv("../Resources/clean_data/Population/pop_2017.csv")

# %%
# Change column names
census.rename(columns={'State': 'NAME'}, inplace=True)

# %%
df = pd.merge(census, pop, on='NAME', how='left').fillna(method='ffill')

# %%
# Change column names
df.rename(columns={'Year_x': 'Year'}, inplace=True)

# %%
# Delete Year_y column 
del df['Year_y']

# %%
df.head()
# Out:
#    Year        NAME  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2017     Alabama                   6.4                      19.1
# 1  2017      Alaska                   2.3                       1.9
# 2  2017     Arizona                   2.4                       5.5
# 3  2017    Arkansas                   7.0                      22.3
# 4  2017  California                   1.0                       1.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        58.5                        11.6
# 1                        49.9                        36.4
# 2                        58.1                        23.8
# 3                        59.1                         8.7
# 4                        16.6                        28.5
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         3.0                         0.8
# 1                         7.4                         1.4
# 2                         6.7                         2.0
# 3                         1.7                         0.7
# 4                        24.6                        13.1
#
#    Home Value $500k+ (%)  Median Home Value ($)(1000X)  ...  \
# 0                    0.7                         158.0  ...
# 1                    0.5                         286.9  ...
# 2                    1.4                         238.8  ...
# 3                    0.4                         142.8  ...
# 4                   15.2                         529.0  ...
#
#    Income $75k-$99,999 (%)  Income $100k-$149,999 (%)  Income $150k+ (%)  \
# 0                     16.2                       20.6               13.0
# 1                     16.4                       26.8               26.1
# 2                     16.1                       20.7               17.3
# 3                     16.9                       17.8               12.5
# 4                     13.6                       22.6               32.5
#
#    Median Income ($)(1000X)  Median Housing Cost (monthly) ($)  Region  \
# 0                    74.553                                0.2       3
# 1                   103.942                                0.0       4
# 2                    80.853                                0.1       4
# 3                    71.081                                0.3       3
# 4                   108.609                                0.0       4
#
#    Population  Net Population Change  Net Migration  Net Migration Change
# 0     4874486                  10961           5309              1.090366
# 1      739700                  -1756          -8141            -10.992765
# 2     7044008                 102936          76071             10.878879
# 3     3001345                  11427           6020              2.009593
# 4    39358497                 191380         -24732             -0.629909
#
# [5 rows x 30 columns]

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Merged/2017.csv"
df.to_csv(file_path, index=False)
