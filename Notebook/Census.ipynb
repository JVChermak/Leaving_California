# %%
# Import our dependencies
import pandas as pd

# %%
# Read in our data
census_2010 = pd.read_csv("../Resources/clean_data/Cost/census_2010.csv")
census_2010.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2010     Alabama                   9.1                      23.6
# 1  2010      Alaska                   2.0                       2.9
# 2  2010     Arizona                   4.0                      13.4
# 3  2010    Arkansas                  12.0                      27.0
# 4  2010  California                   1.5                       3.4
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        20.3                        17.8
# 1                         9.6                        15.6
# 2                        20.5                        19.5
# 3                        23.9                        16.2
# 4                         6.0                         8.6
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.8                         8.7
# 1                        35.2                        26.5
# ...

# %%
# Read in our data
census_2011 = pd.read_csv("../Resources/clean_data/Cost/census_2011.csv")
census_2011.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2011     Alabama                   8.7                      22.4
# 1  2011      Alaska                   2.0                       2.9
# 2  2011     Arizona                   5.2                      18.0
# 3  2011    Arkansas                  11.0                      29.6
# 4  2011  California                   1.6                       3.8
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        22.2                        18.5
# 1                         6.2                        17.6
# 2                        21.7                        18.0
# 3                        22.0                        16.0
# 4                         7.0                         9.0
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.2                         8.7
# 1                        36.3                        27.7
# ...

# %%
# Read in our data
census_2012 = pd.read_csv("../Resources/clean_data/Cost/census_2012.csv")
census_2012.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2012     Alabama                   8.5                      23.0
# 1  2012      Alaska                   2.3                       2.7
# 2  2012     Arizona                   5.7                      18.3
# 3  2012    Arkansas                  11.0                      28.7
# 4  2012  California                   1.7                       4.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        21.7                        17.9
# 1                         7.4                        14.3
# 2                        21.9                        17.0
# 3                        22.6                        16.1
# 4                         7.2                         9.3
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.8                         9.0
# 1                        38.1                        28.9
# ...

# %%
# Read in our data
census_2013 = pd.read_csv("../Resources/clean_data/Cost/census_2013.csv")
census_2013.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2013     Alabama                   9.0                      22.2
# 1  2013      Alaska                   1.9                       2.5
# 2  2013     Arizona                   5.4                      13.2
# 3  2013    Arkansas                  11.3                      26.7
# 4  2013  California                   2.8                       3.2
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        22.3                        17.4
# 1                         6.5                        15.4
# 2                        19.4                        18.5
# 3                        23.8                        16.2
# 4                         5.7                         8.0
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        16.7                         9.3
# 1                        36.4                        30.4
# ...

# %%
# Read in our data
census_2014 = pd.read_csv("../Resources/clean_data/Cost/census_2014.csv")
census_2014.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2014     Alabama                   8.8                      21.6
# 1  2014      Alaska                   2.6                       2.5
# 2  2014     Arizona                   4.9                      11.0
# 3  2014    Arkansas                  10.4                      26.2
# 4  2014  California                   2.7                       2.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        21.5                        17.2
# 1                         5.7                        15.4
# 2                        16.7                        19.0
# 3                        23.4                        17.2
# 4                         4.1                         6.2
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                        18.2                         9.7
# 1                        35.6                        30.9
# ...

# %%
# Read in our data
census_2015 = pd.read_csv("../Resources/clean_data/Cost/census_2015.csv")
census_2015.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2015     Alabama                   6.5                      21.6
# 1  2015      Alaska                   1.5                       2.3
# 2  2015     Arizona                   2.7                       9.1
# 3  2015    Arkansas                   7.7                      23.9
# 4  2015  California                   1.1                       1.7
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        57.3                        10.7
# 1                        54.6                        33.0
# 2                        60.0                        19.2
# 3                        57.1                         7.9
# 4                        22.2                        30.5
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         2.5                         0.8
# 1                         6.7                         1.4
# ...

# %%
# Read in our data
census_2016 = pd.read_csv("../Resources/clean_data/Cost/census_2016.csv")
census_2016.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2016     Alabama                   6.6                      19.7
# 1  2016      Alaska                   2.0                       2.4
# 2  2016     Arizona                   2.6                       7.4
# 3  2016    Arkansas                   7.3                      23.3
# 4  2016  California                   1.1                       1.4
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        58.8                        11.0
# 1                        49.7                        36.0
# 2                        60.0                        21.2
# 3                        57.8                         8.6
# 4                        19.4                        29.4
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         2.4                         0.9
# 1                         7.7                         1.5
# ...

# %%
# Read in our data
census_2017 = pd.read_csv("../Resources/clean_data/Cost/census_2017.csv")
census_2017.head()
# Out:
#    Year       State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2017     Alabama                   6.4                      19.1
# 1  2017      Alaska                   2.3                       1.9
# 2  2017     Arizona                   2.4                       5.5
# 3  2017    Arkansas                   7.0                      22.3
# 4  2017  California                   1.0                       1.1
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        58.5                        11.6
# 1                        49.9                        36.4
# 2                        58.1                        23.8
# 3                        59.1                         8.7
# 4                        16.6                        28.5
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         3.0                         0.8
# 1                         7.4                         1.4
# ...

# %%
# Read in our data
census_2018 = pd.read_csv("../Resources/clean_data/Cost/census_2018.csv")
census_2018.head()
# Out:
#    Year           State  Home Value <$50k (%)  Home Value $50k-$90k (%)  \
# 0  2018          Alaska                   1.3                       2.4
# 1  2018           Maine                   3.4                       9.1
# 2  2018  North Carolina                   2.9                      11.7
# 3  2018        Missouri                   4.9                      15.4
# 4  2018    Pennsylvania                   3.4                      11.9
#
#    Home Value $100k-$149k (%)  Home Value $150k-$199k (%)  \
# 0                        49.0                        36.6
# 1                        62.4                        18.8
# 2                        58.1                        19.0
# 3                        60.7                        13.7
# 4                        57.6                        19.2
#
#    Home Value $200k-$299k (%)  Home Value $300k-$499k (%)  \
# 0                         8.2                         1.8
# 1                         4.1                         1.1
# ...

# %%
# Combine all the dfs
census = pd.concat([census_2010, census_2011, census_2012, census_2013, census_2014, census_2015, census_2016, census_2017, census_2018], sort=True)
census
# Out:
#     2nd Mortgage Only (%)  2nd Mortgage or Equity Loan (%)  \
# 0                     4.9                             17.2
# 1                     4.5                             14.9
# 2                     5.8                             21.8
# 3                     4.1                             10.5
# 4                     7.6                             26.3
# ..                    ...                              ...
# 47                    2.0                             10.5
# 48                    2.3                             18.1
# 49                    3.3                             15.6
# 50                    3.7                             14.7
# 51                    1.5                             13.8
#
#     Both 2nd & Equity Loan (%)  Equity Loan Only (%)  \
# 0                          0.6                  12.3
# 1                          0.7                  10.4
# 2                          0.8                  16.0
# ...

# %%
# Reset the index
census.reset_index(drop=True, inplace=True)
census
# Out:
#      2nd Mortgage Only (%)  2nd Mortgage or Equity Loan (%)  \
# 0                      4.9                             17.2
# 1                      4.5                             14.9
# 2                      5.8                             21.8
# 3                      4.1                             10.5
# 4                      7.6                             26.3
# ..                     ...                              ...
# 463                    2.0                             10.5
# 464                    2.3                             18.1
# 465                    3.3                             15.6
# 466                    3.7                             14.7
# 467                    1.5                             13.8
#
#      Both 2nd & Equity Loan (%)  Equity Loan Only (%)  \
# 0                           0.6                  12.3
# 1                           0.7                  10.4
# 2                           0.8                  16.0
# ...

# %%
# Saving cleaned data
file_path = "../Resources/clean_data/Cost/Census.csv"
census.to_csv(file_path, index=False)
